# %% [markdown]
# <a href="https://colab.research.google.com/github/MichalMaczek/praca_inz/blob/main/Clustering_Plots.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # METRICS DEPENDING ON THRESHOLD - 32 bins

# %%
import pandas as pd
import numpy as np
import os
import glob
import matplotlib.pyplot as plt



from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ##RECALL

# %%
num_of_bins = 32
multiplier = [0.01 * n for n in range(1, 10)]
EPS = [ x * num_of_bins for x in multiplier]

# %%
recall_0 = pd.read_csv('/content/drive/MyDrive/Inż/Plots/recall_32_0_adap.csv', sep=',', names=['x'])
recall_0 = recall_0['x'].tolist()
recall_50 = pd.read_csv('/content/drive/MyDrive/Inż/Plots/recall_32_50_adap.csv', sep=',', names=['x'])
recall_50 = recall_50['x'].tolist()
recall_100 = pd.read_csv('/content/drive/MyDrive/Inż/Plots/recall_32_100_adap.csv', sep=',', names=['x'])
recall_100 = recall_100['x'].tolist()
recall_150 = pd.read_csv('/content/drive/MyDrive/Inż/Plots/recall_32_150_adap.csv', sep=',', names=['x'])
recall_150 = recall_150['x'].tolist()
recall_300 = pd.read_csv('/content/drive/MyDrive/Inż/Plots/recall_32_300_adap.csv', sep=',', names=['x'])
recall_300 = recall_300['x'].tolist()

# %%
title = "No of bins: " + str(num_of_bins) + " - " + "Recall"
plt.plot(EPS, recall_0, label = "m = 0", marker = "o")
plt.plot(EPS, recall_50, label = "m = 50", marker = "o")
plt.plot(EPS, recall_100, label = "m = 100", marker = "*")
plt.plot(EPS, recall_150, label = "m = 150", linestyle = "-", marker = "o")
plt.plot(EPS, recall_300, label = "m = 300", linestyle = "-", marker = "x")
plt.title(title)
plt.legend()
plt.show()

# %% [markdown]
# ##PRECISION

# %%
precision_0 = pd.read_csv('/content/drive/MyDrive/Inż/Plots/precision_32_0_adap.csv', sep=',', names=['x'])
precision_0 = precision_0['x'].tolist()
precision_50 = pd.read_csv('/content/drive/MyDrive/Inż/Plots/precision_32_50_adap.csv', sep=',', names=['x'])
precision_50 = precision_50['x'].tolist()
precision_100 = pd.read_csv('/content/drive/MyDrive/Inż/Plots/precision_32_100_adap.csv', sep=',', names=['x'])
precision_100 = precision_100['x'].tolist()
precision_150 = pd.read_csv('/content/drive/MyDrive/Inż/Plots/precision_32_150_adap.csv', sep=',', names=['x'])
precision_150 = precision_150['x'].tolist()
precision_300 = pd.read_csv('/content/drive/MyDrive/Inż/Plots/precision_32_300_adap.csv', sep=',', names=['x'])
precision_300 = precision_300['x'].tolist()

# %%
title = "No of bins: " + str(num_of_bins) + " - " + "Precision"
plt.plot(EPS, precision_0, label = "m = 0", marker = "o")
plt.plot(EPS, precision_50, label = "m = 50", marker = "x")
plt.plot(EPS, precision_100, label = "m = 100", marker = "*")
plt.plot(EPS, precision_150, label = "m = 150", linestyle = "-", marker = "o")
plt.plot(EPS, precision_300, label = "m = 300", linestyle = "-", marker = "x")
plt.title(title)
plt.legend()
plt.show()

# %% [markdown]
# ##F1 SCORE

# %%
f1_score_0 = pd.read_csv('/content/drive/MyDrive/Inż/Plots/f1_score_32_0_adap.csv', sep=',', names=['x'])
f1_score_0 = f1_score_0['x'].tolist()
f1_score_50 = pd.read_csv('/content/drive/MyDrive/Inż/Plots/f1_score_32_50_adap.csv', sep=',', names=['x'])
f1_score_50 = f1_score_50['x'].tolist()
f1_score_100 = pd.read_csv('/content/drive/MyDrive/Inż/Plots/f1_score_32_100_adap.csv', sep=',', names=['x'])
f1_score_100 = f1_score_100['x'].tolist()
f1_score_150 = pd.read_csv('/content/drive/MyDrive/Inż/Plots/f1_score_32_150_adap.csv', sep=',', names=['x'])
f1_score_150 = f1_score_150['x'].tolist()
f1_score_300 = pd.read_csv('/content/drive/MyDrive/Inż/Plots/f1_score_32_300_adap.csv', sep=',', names=['x'])
f1_score_300 = f1_score_300['x'].tolist()

# %%
title = "No of bins: " + str(num_of_bins) + " - " + "F1 Score"
plt.plot(EPS, f1_score_0, label = "m = 0", marker = "o")
plt.plot(EPS, f1_score_50, label = "m = 50", marker = "x")
plt.plot(EPS, f1_score_100, label = "m = 100", marker = "*")
plt.plot(EPS, f1_score_150, label = "m = 150", linestyle = "-", marker = "o")
plt.plot(EPS, f1_score_300, label = "m = 300", linestyle = "-", marker = "x")
plt.title(title)
plt.legend()
plt.show()

# %% [markdown]
# # METRICS DEPENDING ON THRESHOLD - 64 bins

# %% [markdown]
# ##RECALL

# %%
num_of_bins = 64
multiplier = [0.01 * n for n in range(1, 10)]
EPS = [ x * num_of_bins for x in multiplier]

# %%
recall_0 = pd.read_csv('/content/drive/MyDrive/Inż/Plots/recall_64_0_adap.csv', sep=',', names=['x'])
recall_0 = recall_0['x'].tolist()
recall_50 = pd.read_csv('/content/drive/MyDrive/Inż/Plots/recall_64_50_adap.csv', sep=',', names=['x'])
recall_50 = recall_50['x'].tolist()
recall_100 = pd.read_csv('/content/drive/MyDrive/Inż/Plots/recall_64_100_adap.csv', sep=',', names=['x'])
recall_100 = recall_100['x'].tolist()
recall_150 = pd.read_csv('/content/drive/MyDrive/Inż/Plots/recall_64_150_adap.csv', sep=',', names=['x'])
recall_150 = recall_150['x'].tolist()
recall_300 = pd.read_csv('/content/drive/MyDrive/Inż/Plots/recall_64_300_adap.csv', sep=',', names=['x'])
recall_300 = recall_300['x'].tolist()

# %%
title = "No of bins: " + str(num_of_bins) + " - " + "Recall"
plt.plot(EPS, recall_0, label = "m = 0", marker = "o")
plt.plot(EPS, recall_50, label = "m = 50", marker = "x")
plt.plot(EPS, recall_100, label = "m = 100", marker = "*")
plt.plot(EPS, recall_150, label = "m = 150", linestyle = "-", marker = "o")
plt.plot(EPS, recall_300, label = "m = 300", linestyle = "-", marker = "x")
plt.title(title)
plt.legend()
plt.show()

# %% [markdown]
# ##PRECISION

# %%
precision_0 = pd.read_csv('/content/drive/MyDrive/Inż/Plots/precision_64_0_adap.csv', sep=',', names=['x'])
precision_0 = precision_0['x'].tolist()
precision_50 = pd.read_csv('/content/drive/MyDrive/Inż/Plots/precision_64_50_adap.csv', sep=',', names=['x'])
precision_50 = precision_50['x'].tolist()
precision_100 = pd.read_csv('/content/drive/MyDrive/Inż/Plots/precision_64_100_adap.csv', sep=',', names=['x'])
precision_100 = precision_100['x'].tolist()
precision_150 = pd.read_csv('/content/drive/MyDrive/Inż/Plots/precision_64_150_adap.csv', sep=',', names=['x'])
precision_150 = precision_150['x'].tolist()
precision_300 = pd.read_csv('/content/drive/MyDrive/Inż/Plots/precision_64_300_adap.csv', sep=',', names=['x'])
precision_300 = precision_300['x'].tolist()

# %%
title = "No of bins: " + str(num_of_bins) + " - " + "Precision"
plt.plot(EPS, precision_0, label = "m = 0", marker = "o")
plt.plot(EPS, precision_50, label = "m = 50", marker = "x")
plt.plot(EPS, precision_100, label = "m = 100", marker = "*")
plt.plot(EPS, precision_150, label = "m = 150", linestyle = "-", marker = "o")
plt.plot(EPS, precision_300, label = "m = 300", linestyle = "-", marker = "x")
plt.title(title)
plt.legend()
plt.show()

# %% [markdown]
# ##F1 SCORE

# %%
f1_score_0 = pd.read_csv('/content/drive/MyDrive/Inż/Plots/f1_score_64_0_adap.csv', sep=',', names=['x'])
f1_score_0 = f1_score_0['x'].tolist()
f1_score_50 = pd.read_csv('/content/drive/MyDrive/Inż/Plots/f1_score_64_50_adap.csv', sep=',', names=['x'])
f1_score_50 = f1_score_50['x'].tolist()
f1_score_100 = pd.read_csv('/content/drive/MyDrive/Inż/Plots/f1_score_64_100_adap.csv', sep=',', names=['x'])
f1_score_100 = f1_score_100['x'].tolist()
f1_score_150 = pd.read_csv('/content/drive/MyDrive/Inż/Plots/f1_score_64_150_adap.csv', sep=',', names=['x'])
f1_score_150 = f1_score_150['x'].tolist()
f1_score_300 = pd.read_csv('/content/drive/MyDrive/Inż/Plots/f1_score_64_300_adap.csv', sep=',', names=['x'])
f1_score_300 = f1_score_300['x'].tolist()

# %%
title = "No of bins: " + str(num_of_bins) + " - " + "F1 Score"
plt.plot(EPS, f1_score_0, label = "m = 0", marker = "o")
plt.plot(EPS, f1_score_50, label = "m = 50", marker = "x")
plt.plot(EPS, f1_score_100, label = "m = 100", marker = "*")
plt.plot(EPS, f1_score_150, label = "m = 150", linestyle = "-", marker = "o")
plt.plot(EPS, f1_score_300, label = "m = 300", linestyle = "-", marker = "x")
plt.title(title)
plt.legend()
plt.show()

# %% [markdown]
# # METRICS DEPENDING ON THRESHOLD - 128 bins

# %% [markdown]
# ##RECALL

# %%
num_of_bins = 128
multiplier = [0.01 * n for n in range(1, 10)]
EPS = [ x * num_of_bins for x in multiplier]

# %%
recall_0 = pd.read_csv('/content/drive/MyDrive/Inż/Plots/recall_128_0_adap.csv', sep=',', names=['x'])
recall_0 = recall_0['x'].tolist()
recall_50 = pd.read_csv('/content/drive/MyDrive/Inż/Plots/recall_128_50_adap.csv', sep=',', names=['x'])
recall_50 = recall_50['x'].tolist()
recall_100 = pd.read_csv('/content/drive/MyDrive/Inż/Plots/recall_128_100_adap.csv', sep=',', names=['x'])
recall_100 = recall_100['x'].tolist()
recall_150 = pd.read_csv('/content/drive/MyDrive/Inż/Plots/recall_128_150_adap.csv', sep=',', names=['x'])
recall_150 = recall_150['x'].tolist()
recall_300 = pd.read_csv('/content/drive/MyDrive/Inż/Plots/recall_128_300_adap.csv', sep=',', names=['x'])
recall_300 = recall_300['x'].tolist()

# %%
title = "No of bins: " + str(num_of_bins) + " - " + "Recall"
plt.plot(EPS, recall_0, label = "m = 0", marker = "o")
plt.plot(EPS, recall_50, label = "m = 50", marker = "x")
plt.plot(EPS, recall_100, label = "m = 100", marker = "o")
plt.plot(EPS, recall_150, label = "m = 150", linestyle = "-", marker = "x")
plt.plot(EPS, recall_300, label = "m = 300", linestyle = "-", marker = "x")
plt.title(title)
plt.legend()
plt.show()

# %% [markdown]
# ##PRECISION

# %%
precision_0 = pd.read_csv('/content/drive/MyDrive/Inż/Plots/precision_128_0_adap.csv', sep=',', names=['x'])
precision_0 = precision_0['x'].tolist()
precision_50 = pd.read_csv('/content/drive/MyDrive/Inż/Plots/precision_128_50_adap.csv', sep=',', names=['x'])
precision_50 = precision_50['x'].tolist()
precision_100 = pd.read_csv('/content/drive/MyDrive/Inż/Plots/precision_128_100_adap.csv', sep=',', names=['x'])
precision_100 = precision_100['x'].tolist()
precision_150 = pd.read_csv('/content/drive/MyDrive/Inż/Plots/precision_128_150_adap.csv', sep=',', names=['x'])
precision_150 = precision_150['x'].tolist()
precision_300 = pd.read_csv('/content/drive/MyDrive/Inż/Plots/precision_128_300_adap.csv', sep=',', names=['x'])
precision_300 = precision_300['x'].tolist()

# %%
title = "No of bins: " + str(num_of_bins) + " - " + "Precision"
plt.plot(EPS, precision_0, label = "m = 0", marker = "o")
plt.plot(EPS, precision_50, label = "m = 50", marker = "x")
plt.plot(EPS, precision_100, label = "m = 100", marker = "*")
plt.plot(EPS, precision_150, label = "m = 150", linestyle = "-", marker = "o")
plt.plot(EPS, precision_300, label = "m = 300", linestyle = "-", marker = "x")
plt.title(title)
plt.legend()
plt.show()

# %% [markdown]
# ##F1 SCORE

# %%
f1_score_0 = pd.read_csv('/content/drive/MyDrive/Inż/Plots/f1_score_128_0_adap.csv', sep=',', names=['x'])
f1_score_0 = f1_score_0['x'].tolist()
f1_score_50 = pd.read_csv('/content/drive/MyDrive/Inż/Plots/f1_score_128_50_adap.csv', sep=',', names=['x'])
f1_score_50 = f1_score_50['x'].tolist()
f1_score_100 = pd.read_csv('/content/drive/MyDrive/Inż/Plots/f1_score_128_100_adap.csv', sep=',', names=['x'])
f1_score_100 = f1_score_100['x'].tolist()
f1_score_150 = pd.read_csv('/content/drive/MyDrive/Inż/Plots/f1_score_128_150_adap.csv', sep=',', names=['x'])
f1_score_150 = f1_score_150['x'].tolist()
f1_score_300 = pd.read_csv('/content/drive/MyDrive/Inż/Plots/f1_score_128_300_adap.csv', sep=',', names=['x'])
f1_score_300 = f1_score_300['x'].tolist()

# %%
title = "No of bins: " + str(num_of_bins) + " - " + "F1 Score"
plt.plot(EPS, f1_score_0, label = "m = 0", marker = "o")
plt.plot(EPS, f1_score_50, label = "m = 50", marker = "x")
plt.plot(EPS, f1_score_100, label = "m = 100", marker = "*")
plt.plot(EPS, f1_score_150, label = "m = 150", linestyle = "-", marker = "o")
plt.plot(EPS, f1_score_300, label = "m = 300", linestyle = "-", marker = "x")
plt.title(title)
plt.legend()
plt.show()

# %% [markdown]
# # METRICS DEPENDING ON THRESHOLD - 256 bins

# %% [markdown]
# ##RECALL

# %%
num_of_bins = 256
multiplier = [0.01 * n for n in range(1, 10)]
EPS = [ x * num_of_bins for x in multiplier]

# %%
recall_0 = pd.read_csv('/content/drive/MyDrive/Inż/Plots/recall_256_0_adap.csv', sep=',', names=['x'])
recall_0 = recall_0['x'].tolist()
recall_50 = pd.read_csv('/content/drive/MyDrive/Inż/Plots/recall_256_50_adap.csv', sep=',', names=['x'])
recall_50 = recall_50['x'].tolist()
recall_100 = pd.read_csv('/content/drive/MyDrive/Inż/Plots/recall_256_100_adap.csv', sep=',', names=['x'])
recall_100 = recall_100['x'].tolist()
recall_150 = pd.read_csv('/content/drive/MyDrive/Inż/Plots/recall_256_150_adap.csv', sep=',', names=['x'])
recall_150 = recall_150['x'].tolist()
recall_300 = pd.read_csv('/content/drive/MyDrive/Inż/Plots/recall_256_300_adap.csv', sep=',', names=['x'])
recall_300 = recall_300['x'].tolist()

# %%
title = "No of bins: " + str(num_of_bins) + " - " + "Recall"
plt.plot(EPS, recall_0, label = "m = 0", marker = "o")
plt.plot(EPS, recall_50, label = "m = 50", marker = "x")
plt.plot(EPS, recall_100, label = "m = 100", marker = "*")
plt.plot(EPS, recall_150, label = "m = 150", linestyle = "-", marker = "o")
plt.plot(EPS, recall_300, label = "m = 300", linestyle = "-", marker = "x")
plt.title(title)
plt.legend()
plt.show()

# %% [markdown]
# ##PRECISION

# %%
precision_0 = pd.read_csv('/content/drive/MyDrive/Inż/Plots/precision_256_0_adap.csv', sep=',', names=['x'])
precision_0 = precision_0['x'].tolist()
precision_50 = pd.read_csv('/content/drive/MyDrive/Inż/Plots/precision_256_50_adap.csv', sep=',', names=['x'])
precision_50 = precision_50['x'].tolist()
precision_100 = pd.read_csv('/content/drive/MyDrive/Inż/Plots/precision_256_100_adap.csv', sep=',', names=['x'])
precision_100 = precision_100['x'].tolist()
precision_150 = pd.read_csv('/content/drive/MyDrive/Inż/Plots/precision_256_150_adap.csv', sep=',', names=['x'])
precision_150 = precision_150['x'].tolist()
precision_300 = pd.read_csv('/content/drive/MyDrive/Inż/Plots/precision_256_300_adap.csv', sep=',', names=['x'])
precision_300 = precision_300['x'].tolist()

# %%
title = "No of bins: " + str(num_of_bins) + " - " + "Precision"
plt.plot(EPS, precision_0, label = "m = 0", marker = "o")
plt.plot(EPS, precision_50, label = "m = 50", marker = "x")
plt.plot(EPS, precision_100, label = "m = 100", marker = "*")
plt.plot(EPS, precision_150, label = "m = 150", linestyle = "-", marker = "o")
plt.plot(EPS, precision_300, label = "m = 300", linestyle = "-", marker = "x")
plt.title(title)
plt.legend()
plt.show()

# %% [markdown]
# ##F1 SCORE

# %%
f1_score_0 = pd.read_csv('/content/drive/MyDrive/Inż/Plots/f1_score_256_0_adap.csv', sep=',', names=['x'])
f1_score_0 = f1_score_0['x'].tolist()
f1_score_50 = pd.read_csv('/content/drive/MyDrive/Inż/Plots/f1_score_256_50_adap.csv', sep=',', names=['x'])
f1_score_50 = f1_score_50['x'].tolist()
f1_score_100 = pd.read_csv('/content/drive/MyDrive/Inż/Plots/f1_score_256_100_adap.csv', sep=',', names=['x'])
f1_score_100 = f1_score_100['x'].tolist()
f1_score_150 = pd.read_csv('/content/drive/MyDrive/Inż/Plots/f1_score_256_150_adap.csv', sep=',', names=['x'])
f1_score_150 = f1_score_150['x'].tolist()
f1_score_300 = pd.read_csv('/content/drive/MyDrive/Inż/Plots/f1_score_256_300_adap.csv', sep=',', names=['x'])
f1_score_300 = f1_score_300['x'].tolist()

# %%
title = "No of bins: " + str(num_of_bins) + " - " + "F1 Score"
plt.plot(EPS, f1_score_0, label = "m = 0", marker = "o")
plt.plot(EPS, f1_score_50, label = "m = 50", marker = "x")
plt.plot(EPS, f1_score_100, label = "m = 100", marker = "*")
plt.plot(EPS, f1_score_150, label = "m = 150", linestyle = "-", marker = "o")
plt.plot(EPS, f1_score_300, label = "m = 300", linestyle = "-", marker = "x")
plt.title(title)
plt.legend()
plt.show()

# %% [markdown]
# # METRICS DEPENDING ON THRESHOLD - 512 bins

# %% [markdown]
# ##RECALL

# %%
num_of_bins = 512
mp = [0.01 * n for n in range(1, 10)]
mult = []
for i in range(len(mp)):
  b = str(mp[i]) + "b"
  mult.append(b)
# threshold = 150

# %%
recall_0 = pd.read_csv('/content/drive/MyDrive/Inż/Plots/recall_512_0_adap.csv', sep=',', names=['x'])
recall_0 = recall_0['x'].tolist()
recall_50 = pd.read_csv('/content/drive/MyDrive/Inż/Plots/recall_512_50_adap.csv', sep=',', names=['x'])
recall_50 = recall_50['x'].tolist()
recall_100 = pd.read_csv('/content/drive/MyDrive/Inż/Plots/recall_512_100_adap.csv', sep=',', names=['x'])
recall_100 = recall_100['x'].tolist()
recall_150 = pd.read_csv('/content/drive/MyDrive/Inż/Plots/recall_512_150_adap.csv', sep=',', names=['x'])
recall_150 = recall_150['x'].tolist()
recall_300 = pd.read_csv('/content/drive/MyDrive/Inż/Plots/recall_512_300_adap.csv', sep=',', names=['x'])
recall_300 = recall_300['x'].tolist()

# %%
title = "No of bins: " + str(num_of_bins) + " - " + "Recall"
plt.plot(mult, recall_0, label = "m = 0", marker = "o")
plt.plot(mult, recall_50, label = "m = 50", marker = "x")
plt.plot(mult, recall_100, label = "m = 100", marker = "*")
plt.plot(mult, recall_150, label = "m = 150", linestyle = "-", marker = "o")
plt.plot(mult, recall_300, label = "m = 300", linestyle = "-", marker = "x")
plt.xlabel('EPS', fontsize=12)
plt.ylim(0.45, 1)
plt.grid(True, linestyle='--', linewidth=0.5)
plt.title(title, fontsize=20)
plt.legend()
plt.show()

# %% [markdown]
# ##PRECISION

# %%
precision_0 = pd.read_csv('/content/drive/MyDrive/Inż/Plots/precision_512_0_adap.csv', sep=',', names=['x'])
precision_0 = precision_0['x'].tolist()
precision_50 = pd.read_csv('/content/drive/MyDrive/Inż/Plots/precision_512_50_adap.csv', sep=',', names=['x'])
precision_50 = precision_50['x'].tolist()
precision_100 = pd.read_csv('/content/drive/MyDrive/Inż/Plots/precision_512_100_adap.csv', sep=',', names=['x'])
precision_100 = precision_100['x'].tolist()
precision_150 = pd.read_csv('/content/drive/MyDrive/Inż/Plots/precision_512_150_adap.csv', sep=',', names=['x'])
precision_150 = precision_150['x'].tolist()
precision_300 = pd.read_csv('/content/drive/MyDrive/Inż/Plots/precision_512_300_adap.csv', sep=',', names=['x'])
precision_300 = precision_300['x'].tolist()

# %%
title = "No of bins: " + str(num_of_bins) + " - " + "Precision"
plt.plot(mult, precision_0, label = "m = 0", marker = "o")
plt.plot(mult, precision_50, label = "m = 50", marker = "x")
plt.plot(mult, precision_100, label = "m = 100", marker = "*")
plt.plot(mult, precision_150, label = "m = 150", linestyle = "-", marker = "o")
plt.plot(mult, precision_300, label = "m = 300", linestyle = "-", marker = "x")
plt.xlabel('EPS', fontsize=12)
plt.ylim(0.28, 1.03)
plt.grid(True, linestyle='--', linewidth=0.5)
plt.title(title, fontsize=20)
plt.legend()
plt.show()

# %% [markdown]
# ##F1 SCORE

# %%
f1_score_0 = pd.read_csv('/content/drive/MyDrive/Inż/Plots/f1_score_512_0_adap.csv', sep=',', names=['x'])
f1_score_0 = f1_score_0['x'].tolist()
f1_score_50 = pd.read_csv('/content/drive/MyDrive/Inż/Plots/f1_score_512_50_adap.csv', sep=',', names=['x'])
f1_score_50 = f1_score_50['x'].tolist()
f1_score_100 = pd.read_csv('/content/drive/MyDrive/Inż/Plots/f1_score_512_100_adap.csv', sep=',', names=['x'])
f1_score_100 = f1_score_100['x'].tolist()
f1_score_150 = pd.read_csv('/content/drive/MyDrive/Inż/Plots/f1_score_512_150_adap.csv', sep=',', names=['x'])
f1_score_150 = f1_score_150['x'].tolist()
f1_score_300 = pd.read_csv('/content/drive/MyDrive/Inż/Plots/f1_score_512_300_adap.csv', sep=',', names=['x'])
f1_score_300 = f1_score_300['x'].tolist()

# %%
title = "F1 Score"
plt.plot(EPS, f1_score_0, label = "m = 0", marker = "o")
plt.plot(EPS, f1_score_50, label = "m = 50", marker = "x")
plt.plot(EPS, f1_score_100, label = "m = 100", marker = "*")
plt.plot(mult, f1_score_150, linestyle = "-", marker = "o")
plt.plot(EPS, f1_score_300, label = "m = 300", linestyle = "-", marker = "x")
plt.xlabel('EPS', fontsize=12)
plt.ylim(0.4, 1)
plt.grid(True, linestyle='--', linewidth=0.5)
plt.title(title, fontsize=20)
plt.legend()
plt.show()
# Out:
# No handles with labels found to put in legend.

# %% [markdown]
# # METRICS DEPENDING ON THRESHOLD - 1024 bins

# %% [markdown]
# ##RECALL

# %%
num_of_bins = 1024
multiplier = [0.01 * n for n in range(1, 10)]
EPS = [ x * num_of_bins for x in multiplier]

# %%
recall_0 = pd.read_csv('/content/drive/MyDrive/Inż/Plots/recall_1024_0_adap.csv', sep=',', names=['x'])
recall_0 = recall_0['x'].tolist()
recall_50 = pd.read_csv('/content/drive/MyDrive/Inż/Plots/recall_1024_50_adap.csv', sep=',', names=['x'])
recall_50 = recall_50['x'].tolist()
recall_100 = pd.read_csv('/content/drive/MyDrive/Inż/Plots/recall_1024_100_adap.csv', sep=',', names=['x'])
recall_100 = recall_100['x'].tolist()
recall_150 = pd.read_csv('/content/drive/MyDrive/Inż/Plots/recall_1024_150_adap.csv', sep=',', names=['x'])
recall_150 = recall_150['x'].tolist()
recall_300 = pd.read_csv('/content/drive/MyDrive/Inż/Plots/recall_1024_300_adap.csv', sep=',', names=['x'])
recall_300 = recall_300['x'].tolist()

# %%
title = "No of bins: " + str(num_of_bins) + " - " + "Recall"
plt.plot(EPS, recall_0, label = "m = 0", marker = "o")
plt.plot(EPS, recall_50, label = "m = 50", marker = "x")
plt.plot(EPS, recall_100, label = "m = 100", marker = "*")
plt.plot(EPS, recall_150, label = "m = 150", linestyle = "-", marker = "o")
plt.plot(EPS, recall_300, label = "m = 300", linestyle = "-", marker = "x")
plt.title(title)
plt.legend()
plt.show()

# %% [markdown]
# ##PRECISION

# %%
precision_0 = pd.read_csv('/content/drive/MyDrive/Inż/Plots/precision_1024_0_adap.csv', sep=',', names=['x'])
precision_0 = precision_0['x'].tolist()
precision_50 = pd.read_csv('/content/drive/MyDrive/Inż/Plots/precision_1024_50_adap.csv', sep=',', names=['x'])
precision_50 = precision_50['x'].tolist()
precision_100 = pd.read_csv('/content/drive/MyDrive/Inż/Plots/precision_1024_100_adap.csv', sep=',', names=['x'])
precision_100 = precision_100['x'].tolist()
precision_150 = pd.read_csv('/content/drive/MyDrive/Inż/Plots/precision_1024_150_adap.csv', sep=',', names=['x'])
precision_150 = precision_150['x'].tolist()
precision_300 = pd.read_csv('/content/drive/MyDrive/Inż/Plots/precision_1024_300_adap.csv', sep=',', names=['x'])
precision_300 = precision_300['x'].tolist()

# %%
title = "No of bins: " + str(num_of_bins) + " - " + "Precision"
plt.plot(EPS, precision_0, label = "m = 0", marker = "o")
plt.plot(EPS, precision_50, label = "m = 50", marker = "x")
plt.plot(EPS, precision_100, label = "m = 100", marker = "*")
plt.plot(EPS, precision_150, label = "m = 150", linestyle = "-", marker = "o")
plt.plot(EPS, precision_300, label = "m = 300", linestyle = "-", marker = "x")
plt.title(title)
plt.legend()
plt.show()

# %% [markdown]
# ##F1 SCORE

# %%
f1_score_0 = pd.read_csv('/content/drive/MyDrive/Inż/Plots/f1_score_1024_0_adap.csv', sep=',', names=['x'])
f1_score_0 = f1_score_0['x'].tolist()
f1_score_50 = pd.read_csv('/content/drive/MyDrive/Inż/Plots/f1_score_1024_50_adap.csv', sep=',', names=['x'])
f1_score_50 = f1_score_50['x'].tolist()
f1_score_100 = pd.read_csv('/content/drive/MyDrive/Inż/Plots/f1_score_1024_100_adap.csv', sep=',', names=['x'])
f1_score_100 = f1_score_100['x'].tolist()
f1_score_150 = pd.read_csv('/content/drive/MyDrive/Inż/Plots/f1_score_1024_150_adap.csv', sep=',', names=['x'])
f1_score_150 = f1_score_150['x'].tolist()
f1_score_300 = pd.read_csv('/content/drive/MyDrive/Inż/Plots/f1_score_1024_300_adap.csv', sep=',', names=['x'])
f1_score_300 = f1_score_300['x'].tolist()

# %%
title = "F1 Score"
plt.plot(EPS, f1_score_0, label = "m = 0", marker = "o")
plt.plot(EPS, f1_score_50, label = "m = 50", marker = "x")
plt.plot(EPS, f1_score_100, label = "m = 100", marker = "*")
plt.plot(mult, f1_score_150 , linestyle = "-", marker = "o")
plt.plot(EPS, f1_score_300, label = "m = 300", linestyle = "-", marker = "x")
plt.xlabel('EPS', fontsize=12)
plt.ylim(0.4, 1)
plt.grid(True, linestyle='--', linewidth=0.5)
plt.title(title, fontsize=20)
plt.legend()
plt.show()
# Out:
# No handles with labels found to put in legend.

# %% [markdown]
# # BINS DEPENDING ON EPS - THRESHOLD 0

# %% [markdown]
# ##RECALL

# %%
mp = [0.01 * n for n in range(1, 10)]
threshold = 0

# %%
recall_32 = pd.read_csv('/content/drive/MyDrive/Inż/Plots/recall_32_0_adap.csv', sep=',', names=['x'])
recall_32 = recall_32['x'].tolist()
recall_64 = pd.read_csv('/content/drive/MyDrive/Inż/Plots/recall_64_0_adap.csv', sep=',', names=['x'])
recall_64 = recall_64['x'].tolist()
recall_128 = pd.read_csv('/content/drive/MyDrive/Inż/Plots/recall_128_0_adap.csv', sep=',', names=['x'])
recall_128 = recall_128['x'].tolist()
recall_256 = pd.read_csv('/content/drive/MyDrive/Inż/Plots/recall_256_0_adap.csv', sep=',', names=['x'])
recall_256 = recall_256['x'].tolist()
recall_512 = pd.read_csv('/content/drive/MyDrive/Inż/Plots/recall_512_0_adap.csv', sep=',', names=['x'])
recall_512 = recall_512['x'].tolist()
recall_1024 = pd.read_csv('/content/drive/MyDrive/Inż/Plots/recall_1024_0_adap.csv', sep=',', names=['x'])
recall_1024 = recall_1024['x'].tolist()

# %%
title = "Threshold: " + str(threshold) + " - " + "Recall"
plt.plot(mp, recall_32, label = "b = 32", marker = "o")
plt.plot(mp, recall_64, label = "b = 64", marker = "x")
plt.plot(mp, recall_128, label = "b = 128", marker = "*")
plt.plot(mp, recall_256, label = "b = 256", linestyle = "-", marker = "o")
plt.plot(mp, recall_512, label = "b = 512", linestyle = "-", marker = "x")
plt.plot(mp, recall_1024, label = "b = 1024", linestyle = "-", marker = "*")
plt.title(title)
plt.legend()
plt.show()

# %% [markdown]
# ##PRECISION

# %%
precision_32 = pd.read_csv('/content/drive/MyDrive/Inż/Plots/precision_32_0_adap.csv', sep=',', names=['x'])
precision_32 = precision_32['x'].tolist()
precision_64 = pd.read_csv('/content/drive/MyDrive/Inż/Plots/precision_64_0_adap.csv', sep=',', names=['x'])
precision_64 = precision_64['x'].tolist()
precision_128 = pd.read_csv('/content/drive/MyDrive/Inż/Plots/precision_128_0_adap.csv', sep=',', names=['x'])
precision_128 = precision_128['x'].tolist()
precision_256 = pd.read_csv('/content/drive/MyDrive/Inż/Plots/precision_256_0_adap.csv', sep=',', names=['x'])
precision_256 = precision_256['x'].tolist()
precision_512 = pd.read_csv('/content/drive/MyDrive/Inż/Plots/precision_512_0_adap.csv', sep=',', names=['x'])
precision_512 = precision_512['x'].tolist()
precision_1024 = pd.read_csv('/content/drive/MyDrive/Inż/Plots/precision_1024_0_adap.csv', sep=',', names=['x'])
precision_1024 = precision_1024['x'].tolist()

# %%
title = "Threshold: " + str(threshold) + " - " + "Precision"
plt.plot(mp, precision_32, label = "b = 32", marker = "o")
plt.plot(mp, precision_64, label = "b = 64", marker = "x")
plt.plot(mp, precision_128, label = "b = 128", marker = "*")
plt.plot(mp, precision_256, label = "b = 256", linestyle = "-", marker = "o")
plt.plot(mp, precision_512, label = "b = 512", linestyle = "-", marker = "x")
plt.plot(mp, precision_1024, label = "b = 1024", linestyle = "-", marker = "*")
plt.title(title)
plt.legend()
plt.show()

# %% [markdown]
# ##F1_SCORE

# %%
f1_score_32 = pd.read_csv('/content/drive/MyDrive/Inż/Plots/f1_score_32_0_adap.csv', sep=',', names=['x'])
f1_score_32 = f1_score_32['x'].tolist()
f1_score_64 = pd.read_csv('/content/drive/MyDrive/Inż/Plots/f1_score_64_0_adap.csv', sep=',', names=['x'])
f1_score_64 = f1_score_64['x'].tolist()
f1_score_128 = pd.read_csv('/content/drive/MyDrive/Inż/Plots/f1_score_128_0_adap.csv', sep=',', names=['x'])
f1_score_128 = f1_score_128['x'].tolist()
f1_score_256 = pd.read_csv('/content/drive/MyDrive/Inż/Plots/f1_score_256_0_adap.csv', sep=',', names=['x'])
f1_score_256 = f1_score_256['x'].tolist()
f1_score_512 = pd.read_csv('/content/drive/MyDrive/Inż/Plots/f1_score_512_0_adap.csv', sep=',', names=['x'])
f1_score_512 = f1_score_512['x'].tolist()
f1_score_1024 = pd.read_csv('/content/drive/MyDrive/Inż/Plots/f1_score_1024_0_adap.csv', sep=',', names=['x'])
f1_score_1024 = f1_score_1024['x'].tolist()

# %%
title = "Threshold: " + str(threshold) + " - " + "F1 Score"
plt.plot(mp, f1_score_32, label = "b = 32", marker = "o")
plt.plot(mp, f1_score_64, label = "b = 64", marker = "x")
plt.plot(mp, f1_score_128, label = "b = 128", marker = "*")
plt.plot(mp, f1_score_256, label = "b = 256", linestyle = "-", marker = "o")
plt.plot(mp, f1_score_512, label = "b = 512", linestyle = "-", marker = "x")
plt.plot(mp, f1_score_1024, label = "b = 1024", linestyle = "-", marker = "*")
plt.title(title)
plt.legend()
plt.show()

# %% [markdown]
# ##NO OF CLUSTERS

# %%
no_of_clusters_32 = pd.read_csv('/content/drive/MyDrive/Inż/Plots/no_of_clusters_32_0_adap.csv', sep=',', names=['x'])
no_of_clusters_32 = no_of_clusters_32['x'].tolist()
no_of_clusters_64 = pd.read_csv('/content/drive/MyDrive/Inż/Plots/no_of_clusters_64_0_adap.csv', sep=',', names=['x'])
no_of_clusters_64 = no_of_clusters_64['x'].tolist()
no_of_clusters_128 = pd.read_csv('/content/drive/MyDrive/Inż/Plots/no_of_clusters_128_0_adap.csv', sep=',', names=['x'])
no_of_clusters_128 = no_of_clusters_128['x'].tolist()
no_of_clusters_256 = pd.read_csv('/content/drive/MyDrive/Inż/Plots/no_of_clusters_256_0_adap.csv', sep=',', names=['x'])
no_of_clusters_256 = no_of_clusters_256['x'].tolist()
no_of_clusters_512 = pd.read_csv('/content/drive/MyDrive/Inż/Plots/no_of_clusters_512_0_adap.csv', sep=',', names=['x'])
no_of_clusters_512 = no_of_clusters_512['x'].tolist()
no_of_clusters_1024 = pd.read_csv('/content/drive/MyDrive/Inż/Plots/no_of_clusters_1024_0_adap.csv', sep=',', names=['x'])
no_of_clusters_1024 = no_of_clusters_1024['x'].tolist()

# %%
title = "Threshold: " + str(threshold) + " - " + "No of clusters"
plt.plot(mp, no_of_clusters_32, label = "b = 32", marker = "o")
plt.plot(mp, no_of_clusters_64, label = "b = 64", marker = "x")
plt.plot(mp, no_of_clusters_128, label = "b = 128", marker = "*")
plt.plot(mp, no_of_clusters_256, label = "b = 256", linestyle = "-", marker = "o")
plt.plot(mp, no_of_clusters_512, label = "b = 512", linestyle = "-", marker = "x")
plt.plot(mp, no_of_clusters_1024, label = "b = 1024", linestyle = "-", marker = "*")
plt.title(title)
plt.legend()
plt.show()

# %% [markdown]
# # BINS DEPENDING ON EPS - THRESHOLD 50

# %% [markdown]
# ##RECALL

# %%
mp = [0.01 * n for n in range(1, 10)]
threshold = 50

# %%
recall_32 = pd.read_csv('/content/drive/MyDrive/Inż/Plots/recall_32_50_adap.csv', sep=',', names=['x'])
recall_32 = recall_32['x'].tolist()
recall_64 = pd.read_csv('/content/drive/MyDrive/Inż/Plots/recall_64_50_adap.csv', sep=',', names=['x'])
recall_64 = recall_64['x'].tolist()
recall_128 = pd.read_csv('/content/drive/MyDrive/Inż/Plots/recall_128_50_adap.csv', sep=',', names=['x'])
recall_128 = recall_128['x'].tolist()
recall_256 = pd.read_csv('/content/drive/MyDrive/Inż/Plots/recall_256_50_adap.csv', sep=',', names=['x'])
recall_256 = recall_256['x'].tolist()
recall_512 = pd.read_csv('/content/drive/MyDrive/Inż/Plots/recall_512_50_adap.csv', sep=',', names=['x'])
recall_512 = recall_512['x'].tolist()
recall_1024 = pd.read_csv('/content/drive/MyDrive/Inż/Plots/recall_1024_50_adap.csv', sep=',', names=['x'])
recall_1024 = recall_1024['x'].tolist()

# %%
title = "Threshold: " + str(threshold) + " - " + "Recall"
plt.plot(mp, recall_32, label = "b = 32", marker = "o")
plt.plot(mp, recall_64, label = "b = 64", marker = "x")
plt.plot(mp, recall_128, label = "b = 128", marker = "*")
plt.plot(mp, recall_256, label = "b = 256", linestyle = "-", marker = "o")
plt.plot(mp, recall_512, label = "b = 512", linestyle = "-", marker = "x")
plt.plot(mp, recall_1024, label = "b = 1024", linestyle = "-", marker = "*")
plt.title(title)
plt.legend()
plt.show()

# %% [markdown]
# ##PRECISION

# %%
precision_32 = pd.read_csv('/content/drive/MyDrive/Inż/Plots/precision_32_50_adap.csv', sep=',', names=['x'])
precision_32 = precision_32['x'].tolist()
precision_64 = pd.read_csv('/content/drive/MyDrive/Inż/Plots/precision_64_50_adap.csv', sep=',', names=['x'])
precision_64 = precision_64['x'].tolist()
precision_128 = pd.read_csv('/content/drive/MyDrive/Inż/Plots/precision_128_50_adap.csv', sep=',', names=['x'])
precision_128 = precision_128['x'].tolist()
precision_256 = pd.read_csv('/content/drive/MyDrive/Inż/Plots/precision_256_50_adap.csv', sep=',', names=['x'])
precision_256 = precision_256['x'].tolist()
precision_512 = pd.read_csv('/content/drive/MyDrive/Inż/Plots/precision_512_50_adap.csv', sep=',', names=['x'])
precision_512 = precision_512['x'].tolist()
precision_1024 = pd.read_csv('/content/drive/MyDrive/Inż/Plots/precision_1024_50_adap.csv', sep=',', names=['x'])
precision_1024 = precision_1024['x'].tolist()

# %%
title = "Threshold: " + str(threshold) + " - " + "Precision"
plt.plot(mp, precision_32, label = "b = 32", marker = "o")
plt.plot(mp, precision_64, label = "b = 64", marker = "x")
plt.plot(mp, precision_128, label = "b = 128", marker = "*")
plt.plot(mp, precision_256, label = "b = 256", linestyle = "-", marker = "o")
plt.plot(mp, precision_512, label = "b = 512", linestyle = "-", marker = "x")
plt.plot(mp, precision_1024, label = "b = 1024", linestyle = "-", marker = "*")
plt.title(title)
plt.legend()
plt.show()

# %% [markdown]
# ##F1_SCORE

# %%
f1_score_32 = pd.read_csv('/content/drive/MyDrive/Inż/Plots/f1_score_32_50_adap.csv', sep=',', names=['x'])
f1_score_32 = f1_score_32['x'].tolist()
f1_score_64 = pd.read_csv('/content/drive/MyDrive/Inż/Plots/f1_score_64_50_adap.csv', sep=',', names=['x'])
f1_score_64 = f1_score_64['x'].tolist()
f1_score_128 = pd.read_csv('/content/drive/MyDrive/Inż/Plots/f1_score_128_50_adap.csv', sep=',', names=['x'])
f1_score_128 = f1_score_128['x'].tolist()
f1_score_256 = pd.read_csv('/content/drive/MyDrive/Inż/Plots/f1_score_256_50_adap.csv', sep=',', names=['x'])
f1_score_256 = f1_score_256['x'].tolist()
f1_score_512 = pd.read_csv('/content/drive/MyDrive/Inż/Plots/f1_score_512_50_adap.csv', sep=',', names=['x'])
f1_score_512 = f1_score_512['x'].tolist()
f1_score_1024 = pd.read_csv('/content/drive/MyDrive/Inż/Plots/f1_score_1024_50_adap.csv', sep=',', names=['x'])
f1_score_1024 = f1_score_1024['x'].tolist()

# %%
title = "Threshold: " + str(threshold) + " - " + "F1 Score"
plt.plot(mp, f1_score_32, label = "b = 32", marker = "o")
plt.plot(mp, f1_score_64, label = "b = 64", marker = "x")
plt.plot(mp, f1_score_128, label = "b = 128", marker = "*")
plt.plot(mp, f1_score_256, label = "b = 256", linestyle = "-", marker = "o")
plt.plot(mp, f1_score_512, label = "b = 512", linestyle = "-", marker = "x")
plt.plot(mp, f1_score_1024, label = "b = 1024", linestyle = "-", marker = "*")
plt.title(title)
plt.legend()
plt.show()

# %% [markdown]
# ##NO OF CLUSTERS

# %%
no_of_clusters_32 = pd.read_csv('/content/drive/MyDrive/Inż/Plots/no_of_clusters_32_50_adap.csv', sep=',', names=['x'])
no_of_clusters_32 = no_of_clusters_32['x'].tolist()
no_of_clusters_64 = pd.read_csv('/content/drive/MyDrive/Inż/Plots/no_of_clusters_64_50_adap.csv', sep=',', names=['x'])
no_of_clusters_64 = no_of_clusters_64['x'].tolist()
no_of_clusters_128 = pd.read_csv('/content/drive/MyDrive/Inż/Plots/no_of_clusters_128_50_adap.csv', sep=',', names=['x'])
no_of_clusters_128 = no_of_clusters_128['x'].tolist()
no_of_clusters_256 = pd.read_csv('/content/drive/MyDrive/Inż/Plots/no_of_clusters_256_50_adap.csv', sep=',', names=['x'])
no_of_clusters_256 = no_of_clusters_256['x'].tolist()
no_of_clusters_512 = pd.read_csv('/content/drive/MyDrive/Inż/Plots/no_of_clusters_512_50_adap.csv', sep=',', names=['x'])
no_of_clusters_512 = no_of_clusters_512['x'].tolist()
no_of_clusters_1024 = pd.read_csv('/content/drive/MyDrive/Inż/Plots/no_of_clusters_1024_50_adap.csv', sep=',', names=['x'])
no_of_clusters_1024 = no_of_clusters_1024['x'].tolist()

# %%
title = "Threshold: " + str(threshold) + " - " + "No of clusters"
plt.plot(mp, no_of_clusters_32, label = "b = 32", marker = "o")
plt.plot(mp, no_of_clusters_64, label = "b = 64", marker = "x")
plt.plot(mp, no_of_clusters_128, label = "b = 128", marker = "*")
plt.plot(mp, no_of_clusters_256, label = "b = 256", linestyle = "-", marker = "o")
plt.plot(mp, no_of_clusters_512, label = "b = 512", linestyle = "-", marker = "x")
plt.plot(mp, no_of_clusters_1024, label = "b = 1024", linestyle = "-", marker = "*")
plt.title(title)
plt.legend()
plt.show()

# %% [markdown]
# # BINS DEPENDING ON EPS - THRESHOLD 100

# %% [markdown]
# ##RECALL

# %%
mp = [0.01 * n for n in range(1, 10)]
threshold = 100

# %%
recall_32 = pd.read_csv('/content/drive/MyDrive/Inż/Plots/recall_32_100_adap.csv', sep=',', names=['x'])
recall_32 = recall_32['x'].tolist()
recall_64 = pd.read_csv('/content/drive/MyDrive/Inż/Plots/recall_64_100_adap.csv', sep=',', names=['x'])
recall_64 = recall_64['x'].tolist()
recall_128 = pd.read_csv('/content/drive/MyDrive/Inż/Plots/recall_128_100_adap.csv', sep=',', names=['x'])
recall_128 = recall_128['x'].tolist()
recall_256 = pd.read_csv('/content/drive/MyDrive/Inż/Plots/recall_256_100_adap.csv', sep=',', names=['x'])
recall_256 = recall_256['x'].tolist()
recall_512 = pd.read_csv('/content/drive/MyDrive/Inż/Plots/recall_512_100_adap.csv', sep=',', names=['x'])
recall_512 = recall_512['x'].tolist()
recall_1024 = pd.read_csv('/content/drive/MyDrive/Inż/Plots/recall_1024_100_adap.csv', sep=',', names=['x'])
recall_1024 = recall_1024['x'].tolist()

# %%
title = "Threshold: " + str(threshold) + " - " + "Recall"
plt.plot(mp, recall_32, label = "b = 32", marker = "o")
plt.plot(mp, recall_64, label = "b = 64", marker = "x")
plt.plot(mp, recall_128, label = "b = 128", marker = "*")
plt.plot(mp, recall_256, label = "b = 256", linestyle = "-", marker = "o")
plt.plot(mp, recall_512, label = "b = 512", linestyle = "-", marker = "x")
plt.plot(mp, recall_1024, label = "b = 1024", linestyle = "-", marker = "*")
plt.title(title)
plt.legend()
plt.show()

# %% [markdown]
# ##PRECISION

# %%
precision_32 = pd.read_csv('/content/drive/MyDrive/Inż/Plots/precision_32_100_adap.csv', sep=',', names=['x'])
precision_32 = precision_32['x'].tolist()
precision_64 = pd.read_csv('/content/drive/MyDrive/Inż/Plots/precision_64_100_adap.csv', sep=',', names=['x'])
precision_64 = precision_64['x'].tolist()
precision_128 = pd.read_csv('/content/drive/MyDrive/Inż/Plots/precision_128_100_adap.csv', sep=',', names=['x'])
precision_128 = precision_128['x'].tolist()
precision_256 = pd.read_csv('/content/drive/MyDrive/Inż/Plots/precision_256_100_adap.csv', sep=',', names=['x'])
precision_256 = precision_256['x'].tolist()
precision_512 = pd.read_csv('/content/drive/MyDrive/Inż/Plots/precision_512_100_adap.csv', sep=',', names=['x'])
precision_512 = precision_512['x'].tolist()
precision_1024 = pd.read_csv('/content/drive/MyDrive/Inż/Plots/precision_1024_100_adap.csv', sep=',', names=['x'])
precision_1024 = precision_1024['x'].tolist()

# %%
title = "Threshold: " + str(threshold) + " - " + "Precision"
plt.plot(mp, precision_32, label = "b = 32", marker = "o")
plt.plot(mp, precision_64, label = "b = 64", marker = "x")
plt.plot(mp, precision_128, label = "b = 128", marker = "*")
plt.plot(mp, precision_256, label = "b = 256", linestyle = "-", marker = "o")
plt.plot(mp, precision_512, label = "b = 512", linestyle = "-", marker = "x")
plt.plot(mp, precision_1024, label = "b = 1024", linestyle = "-", marker = "*")
plt.title(title)
plt.legend()
plt.show()

# %% [markdown]
# ##F1_SCORE

# %%
f1_score_32 = pd.read_csv('/content/drive/MyDrive/Inż/Plots/f1_score_32_100_adap.csv', sep=',', names=['x'])
f1_score_32 = f1_score_32['x'].tolist()
f1_score_64 = pd.read_csv('/content/drive/MyDrive/Inż/Plots/f1_score_64_100_adap.csv', sep=',', names=['x'])
f1_score_64 = f1_score_64['x'].tolist()
f1_score_128 = pd.read_csv('/content/drive/MyDrive/Inż/Plots/f1_score_128_100_adap.csv', sep=',', names=['x'])
f1_score_128 = f1_score_128['x'].tolist()
f1_score_256 = pd.read_csv('/content/drive/MyDrive/Inż/Plots/f1_score_256_100_adap.csv', sep=',', names=['x'])
f1_score_256 = f1_score_256['x'].tolist()
f1_score_512 = pd.read_csv('/content/drive/MyDrive/Inż/Plots/f1_score_512_100_adap.csv', sep=',', names=['x'])
f1_score_512 = f1_score_512['x'].tolist()
f1_score_1024 = pd.read_csv('/content/drive/MyDrive/Inż/Plots/f1_score_1024_100_adap.csv', sep=',', names=['x'])
f1_score_1024 = f1_score_1024['x'].tolist()

# %%
title = "Threshold: " + str(threshold) + " - " + "F1 Score"
plt.plot(mp, f1_score_32, label = "b = 32", marker = "o")
plt.plot(mp, f1_score_64, label = "b = 64", marker = "x")
plt.plot(mp, f1_score_128, label = "b = 128", marker = "*")
plt.plot(mp, f1_score_256, label = "b = 256", linestyle = "-", marker = "o")
plt.plot(mp, f1_score_512, label = "b = 512", linestyle = "-", marker = "x")
plt.plot(mp, f1_score_1024, label = "b = 1024", linestyle = "-", marker = "*")
plt.title(title)
plt.legend()
plt.show()

# %% [markdown]
# ##NO OF CLUSTERS

# %%
no_of_clusters_32 = pd.read_csv('/content/drive/MyDrive/Inż/Plots/no_of_clusters_32_100_adap.csv', sep=',', names=['x'])
no_of_clusters_32 = no_of_clusters_32['x'].tolist()
no_of_clusters_64 = pd.read_csv('/content/drive/MyDrive/Inż/Plots/no_of_clusters_64_100_adap.csv', sep=',', names=['x'])
no_of_clusters_64 = no_of_clusters_64['x'].tolist()
no_of_clusters_128 = pd.read_csv('/content/drive/MyDrive/Inż/Plots/no_of_clusters_128_100_adap.csv', sep=',', names=['x'])
no_of_clusters_128 = no_of_clusters_128['x'].tolist()
no_of_clusters_256 = pd.read_csv('/content/drive/MyDrive/Inż/Plots/no_of_clusters_256_100_adap.csv', sep=',', names=['x'])
no_of_clusters_256 = no_of_clusters_256['x'].tolist()
no_of_clusters_512 = pd.read_csv('/content/drive/MyDrive/Inż/Plots/no_of_clusters_512_100_adap.csv', sep=',', names=['x'])
no_of_clusters_512 = no_of_clusters_512['x'].tolist()
no_of_clusters_1024 = pd.read_csv('/content/drive/MyDrive/Inż/Plots/no_of_clusters_1024_100_adap.csv', sep=',', names=['x'])
no_of_clusters_1024 = no_of_clusters_1024['x'].tolist()

# %%
title = "Threshold: " + str(threshold) + " - " + "No of clusters"
plt.plot(mp, no_of_clusters_32, label = "b = 32", marker = "o")
plt.plot(mp, no_of_clusters_64, label = "b = 64", marker = "x")
plt.plot(mp, no_of_clusters_128, label = "b = 128", marker = "*")
plt.plot(mp, no_of_clusters_256, label = "b = 256", linestyle = "-", marker = "o")
plt.plot(mp, no_of_clusters_512, label = "b = 512", linestyle = "-", marker = "x")
plt.plot(mp, no_of_clusters_1024, label = "b = 1024", linestyle = "-", marker = "*")
plt.title(title)
plt.legend()
plt.show()

# %% [markdown]
# # BINS DEPENDING ON EPS - THRESHOLD 150

# %% [markdown]
# ##RECALL

# %%
mp = [0.01 * n for n in range(1, 10)]
mult = []
for i in range(len(mp)):
  b = str(mp[i]) + "b"
  mult.append(b)
threshold = 150

# %%
mult
# Out:
# ['0.01b',
#  '0.02b',
#  '0.03b',
#  '0.04b',
#  '0.05b',
#  '0.06b',
#  '0.07b',
#  '0.08b',
#  '0.09b']

# %%
recall_32 = pd.read_csv('/content/drive/MyDrive/Inż/Plots/recall_32_150_reg_0-1.csv', sep=',', names=['x'])
recall_32 = recall_32['x'].tolist()
recall_64 = pd.read_csv('/content/drive/MyDrive/Inż/Plots/recall_64_150_reg_0-1.csv', sep=',', names=['x'])
recall_64 = recall_64['x'].tolist()
recall_128 = pd.read_csv('/content/drive/MyDrive/Inż/Plots/recall_128_150_reg_0-1.csv', sep=',', names=['x'])
recall_128 = recall_128['x'].tolist()
recall_256 = pd.read_csv('/content/drive/MyDrive/Inż/Plots/recall_256_150_reg_0-1.csv', sep=',', names=['x'])
recall_256 = recall_256['x'].tolist()
recall_512 = pd.read_csv('/content/drive/MyDrive/Inż/Plots/recall_512_150_reg_0-1.csv', sep=',', names=['x'])
recall_512 = recall_512['x'].tolist()
recall_1024 = pd.read_csv('/content/drive/MyDrive/Inż/Plots/recall_1024_150_reg_0-1.csv', sep=',', names=['x'])
recall_1024 = recall_1024['x'].tolist()

# %%
title = "Czułość"
plt.plot(mult, recall_32, label = "b = 32", marker = "o")
plt.plot(mult, recall_64, label = "b = 64", marker = "x")
plt.plot(mult, recall_128, label = "b = 128", marker = "*")
plt.plot(mult, recall_256, label = "b = 256", linestyle = "-", marker = "o")
plt.plot(mult, recall_512, label = "b = 512", linestyle = "-", marker = "x")
plt.plot(mult, recall_1024, label = "b = 1024", linestyle = "-", marker = "*")
plt.xlabel('EPS', fontsize=12)
plt.ylim(0, 1.02)
plt.grid(True, linestyle='--', linewidth=0.5)
plt.title(title, fontsize=20)
plt.legend()
plt.show()

# %% [markdown]
# ##PRECISION

# %%
precision_32 = pd.read_csv('/content/drive/MyDrive/Inż/Plots/precision_32_150_reg_0-1.csv', sep=',', names=['x'])
precision_32 = precision_32['x'].tolist()
precision_64 = pd.read_csv('/content/drive/MyDrive/Inż/Plots/precision_64_150_reg_0-1.csv', sep=',', names=['x'])
precision_64 = precision_64['x'].tolist()
precision_128 = pd.read_csv('/content/drive/MyDrive/Inż/Plots/precision_128_150_reg_0-1.csv', sep=',', names=['x'])
precision_128 = precision_128['x'].tolist()
precision_256 = pd.read_csv('/content/drive/MyDrive/Inż/Plots/precision_256_150_reg_0-1.csv', sep=',', names=['x'])
precision_256 = precision_256['x'].tolist()
precision_512 = pd.read_csv('/content/drive/MyDrive/Inż/Plots/precision_512_150_reg_0-1.csv', sep=',', names=['x'])
precision_512 = precision_512['x'].tolist()
precision_1024 = pd.read_csv('/content/drive/MyDrive/Inż/Plots/precision_1024_150_reg_0-1.csv', sep=',', names=['x'])
precision_1024 = precision_1024['x'].tolist()

# %%
title = "Precyzja"
plt.plot(mult, precision_32, label = "b = 32", marker = "o")
plt.plot(mult, precision_64, label = "b = 64", marker = "x")
plt.plot(mult, precision_128, label = "b = 128", marker = "*")
plt.plot(mult, precision_256, label = "b = 256", linestyle = "-", marker = "o")
plt.plot(mult, precision_512, label = "b = 512", linestyle = "-", marker = "x")
plt.plot(mult, precision_1024, label = "b = 1024", linestyle = "-", marker = "*")
plt.xlabel('EPS', fontsize=12)
plt.ylim(0, 1)
plt.grid(True, linestyle='--', linewidth=0.5)
plt.title(title, fontsize=20)
plt.legend()
plt.show()

# %% [markdown]
# ##F1_SCORE

# %%
thres = [0, 50, 100 ,150, 300, 450]

# %%
f1_score_32 = pd.read_csv('/content/drive/MyDrive/Inż/Plots/f1_score_32_150_reg_0-1.csv', sep=',', names=['x'])
f1_score_32 = f1_score_32['x'].tolist()
f1_score_64 = pd.read_csv('/content/drive/MyDrive/Inż/Plots/f1_score_64_150_reg_0-1.csv', sep=',', names=['x'])
f1_score_64 = f1_score_64['x'].tolist()
f1_score_128 = pd.read_csv('/content/drive/MyDrive/Inż/Plots/f1_score_128_150_reg_0-1.csv', sep=',', names=['x'])
f1_score_128 = f1_score_128['x'].tolist()
f1_score_256 = pd.read_csv('/content/drive/MyDrive/Inż/Plots/f1_score_256_150_reg_0-1.csv', sep=',', names=['x'])
f1_score_256 = f1_score_256['x'].tolist()
f1_score_512 = pd.read_csv('/content/drive/MyDrive/Inż/Plots/f1_score_512_150_reg_0-1.csv', sep=',', names=['x'])
f1_score_512 = f1_score_512['x'].tolist()
f1_score_1024 = pd.read_csv('/content/drive/MyDrive/Inż/Plots/f1_score_1024_150_reg_0-1.csv', sep=',', names=['x'])
f1_score_1024 = f1_score_1024['x'].tolist()

# %%
title = "Miara F1"
plt.plot(mult, f1_score_32, label = "b = 32", marker = "o")
plt.plot(mult, f1_score_64, label = "b = 64", marker = "x")
plt.plot(mult, f1_score_128, label = "b = 128", marker = "*")
plt.plot(mult, f1_score_256, label = "b = 256", linestyle = "-", marker = "o")
plt.plot(mult, f1_score_512, label = "b = 512", linestyle = "-", marker = "x")
plt.plot(mult, f1_score_1024, label = "b = 1024", linestyle = "-", marker = "*")
plt.xlabel('EPS', fontsize=12)
plt.ylim(0, 1)
plt.grid(True, linestyle='--', linewidth=0.5)
plt.title(title, fontsize=20)
plt.legend()
plt.show()

# %% [markdown]
# ##NO OF CLUSTERS

# %%
no_of_clusters_32 = pd.read_csv('/content/drive/MyDrive/Inż/Plots/no_of_clusters_32_150_reg_0-1.csv', sep=',', names=['x'])
no_of_clusters_32 = no_of_clusters_32['x'].tolist()
no_of_clusters_64 = pd.read_csv('/content/drive/MyDrive/Inż/Plots/no_of_clusters_64_150_reg_0-1.csv', sep=',', names=['x'])
no_of_clusters_64 = no_of_clusters_64['x'].tolist()
no_of_clusters_128 = pd.read_csv('/content/drive/MyDrive/Inż/Plots/no_of_clusters_128_150_reg_0-1.csv', sep=',', names=['x'])
no_of_clusters_128 = no_of_clusters_128['x'].tolist()
no_of_clusters_256 = pd.read_csv('/content/drive/MyDrive/Inż/Plots/no_of_clusters_256_150_reg_0-1.csv', sep=',', names=['x'])
no_of_clusters_256 = no_of_clusters_256['x'].tolist()
no_of_clusters_512 = pd.read_csv('/content/drive/MyDrive/Inż/Plots/no_of_clusters_512_150_reg_0-1.csv', sep=',', names=['x'])
no_of_clusters_512 = no_of_clusters_512['x'].tolist()
no_of_clusters_1024 = pd.read_csv('/content/drive/MyDrive/Inż/Plots/no_of_clusters_1024_150_reg_0-1.csv', sep=',', names=['x'])
no_of_clusters_1024 = no_of_clusters_1024['x'].tolist()

# %%
title = "Liczba klastrów"
plt.plot(mult, no_of_clusters_32, label = "b = 32", marker = "o")
plt.plot(mult, no_of_clusters_64, label = "b = 64", marker = "x")
plt.plot(mult, no_of_clusters_128, label = "b = 128", marker = "*")
plt.plot(mult, no_of_clusters_256, label = "b = 256", linestyle = "-", marker = "o")
plt.plot(mult, no_of_clusters_512, label = "b = 512", linestyle = "-", marker = "x")
plt.plot(mult, no_of_clusters_1024, label = "b = 1024", linestyle = "-", marker = "*")
plt.xlabel('EPS', fontsize=12)
plt.grid(True, linestyle='--', linewidth=0.5)
plt.title(title, fontsize=20)
plt.legend()
plt.show()

# %% [markdown]
# # BINS DEPENDING ON EPS - THRESHOLD 300

# %% [markdown]
# ##RECALL

# %%
mp = [0.01 * n for n in range(1, 10)]
threshold = 300

# %%
recall_32 = pd.read_csv('/content/drive/MyDrive/Inż/Plots/recall_32_300_adap.csv', sep=',', names=['x'])
recall_32 = recall_32['x'].tolist()
recall_64 = pd.read_csv('/content/drive/MyDrive/Inż/Plots/recall_64_300_adap.csv', sep=',', names=['x'])
recall_64 = recall_64['x'].tolist()
recall_128 = pd.read_csv('/content/drive/MyDrive/Inż/Plots/recall_128_300_adap.csv', sep=',', names=['x'])
recall_128 = recall_128['x'].tolist()
recall_256 = pd.read_csv('/content/drive/MyDrive/Inż/Plots/recall_256_300_adap.csv', sep=',', names=['x'])
recall_256 = recall_256['x'].tolist()
recall_512 = pd.read_csv('/content/drive/MyDrive/Inż/Plots/recall_512_300_adap.csv', sep=',', names=['x'])
recall_512 = recall_512['x'].tolist()
recall_1024 = pd.read_csv('/content/drive/MyDrive/Inż/Plots/recall_1024_300_adap.csv', sep=',', names=['x'])
recall_1024 = recall_1024['x'].tolist()

# %%
title = "Threshold: " + str(threshold) + " - " + "Recall"
plt.plot(mp, recall_32, label = "b = 32", marker = "o")
plt.plot(mp, recall_64, label = "b = 64", marker = "x")
plt.plot(mp, recall_128, label = "b = 128", marker = "*")
plt.plot(mp, recall_256, label = "b = 256", linestyle = "-", marker = "o")
plt.plot(mp, recall_512, label = "b = 512", linestyle = "-", marker = "x")
plt.plot(mp, recall_1024, label = "b = 1024", linestyle = "-", marker = "*")
plt.title(title)
plt.legend()
plt.show()

# %% [markdown]
# ##PRECISION

# %%
precision_32 = pd.read_csv('/content/drive/MyDrive/Inż/Plots/precision_32_300_adap.csv', sep=',', names=['x'])
precision_32 = precision_32['x'].tolist()
precision_64 = pd.read_csv('/content/drive/MyDrive/Inż/Plots/precision_64_300_adap.csv', sep=',', names=['x'])
precision_64 = precision_64['x'].tolist()
precision_128 = pd.read_csv('/content/drive/MyDrive/Inż/Plots/precision_128_300_adap.csv', sep=',', names=['x'])
precision_128 = precision_128['x'].tolist()
precision_256 = pd.read_csv('/content/drive/MyDrive/Inż/Plots/precision_256_300_adap.csv', sep=',', names=['x'])
precision_256 = precision_256['x'].tolist()
precision_512 = pd.read_csv('/content/drive/MyDrive/Inż/Plots/precision_512_300_adap.csv', sep=',', names=['x'])
precision_512 = precision_512['x'].tolist()
precision_1024 = pd.read_csv('/content/drive/MyDrive/Inż/Plots/precision_1024_300_adap.csv', sep=',', names=['x'])
precision_1024 = precision_1024['x'].tolist()

# %%
title = "Threshold: " + str(threshold) + " - " + "Precision"
plt.plot(mp, precision_32, label = "b = 32", marker = "o")
plt.plot(mp, precision_64, label = "b = 64", marker = "x")
plt.plot(mp, precision_128, label = "b = 128", marker = "*")
plt.plot(mp, precision_256, label = "b = 256", linestyle = "-", marker = "o")
plt.plot(mp, precision_512, label = "b = 512", linestyle = "-", marker = "x")
plt.plot(mp, precision_1024, label = "b = 1024", linestyle = "-", marker = "*")
plt.title(title)
plt.legend()
plt.show()

# %% [markdown]
# ##F1_SCORE

# %%
f1_score_32 = pd.read_csv('/content/drive/MyDrive/Inż/Plots/f1_score_32_300_adap.csv', sep=',', names=['x'])
f1_score_32 = f1_score_32['x'].tolist()
f1_score_64 = pd.read_csv('/content/drive/MyDrive/Inż/Plots/f1_score_64_300_adap.csv', sep=',', names=['x'])
f1_score_64 = f1_score_64['x'].tolist()
f1_score_128 = pd.read_csv('/content/drive/MyDrive/Inż/Plots/f1_score_128_300_adap.csv', sep=',', names=['x'])
f1_score_128 = f1_score_128['x'].tolist()
f1_score_256 = pd.read_csv('/content/drive/MyDrive/Inż/Plots/f1_score_256_300_adap.csv', sep=',', names=['x'])
f1_score_256 = f1_score_256['x'].tolist()
f1_score_512 = pd.read_csv('/content/drive/MyDrive/Inż/Plots/f1_score_512_300_adap.csv', sep=',', names=['x'])
f1_score_512 = f1_score_512['x'].tolist()
f1_score_1024 = pd.read_csv('/content/drive/MyDrive/Inż/Plots/f1_score_1024_300_adap.csv', sep=',', names=['x'])
f1_score_1024 = f1_score_1024['x'].tolist()

# %%
title = "Threshold: " + str(threshold) + " - " + "F1 Score"
plt.plot(mp, f1_score_32, label = "b = 32", marker = "o")
plt.plot(mp, f1_score_64, label = "b = 64", marker = "x")
plt.plot(mp, f1_score_128, label = "b = 128", marker = "*")
plt.plot(mp, f1_score_256, label = "b = 256", linestyle = "-", marker = "o")
plt.plot(mp, f1_score_512, label = "b = 512", linestyle = "-", marker = "x")
plt.plot(mp, f1_score_1024, label = "b = 1024", linestyle = "-", marker = "*")
plt.title(title)
plt.legend()
plt.show()

# %% [markdown]
# ##NO OF CLUSTERS

# %%
no_of_clusters_32 = pd.read_csv('/content/drive/MyDrive/Inż/Plots/no_of_clusters_32_300_adap.csv', sep=',', names=['x'])
no_of_clusters_32 = no_of_clusters_32['x'].tolist()
no_of_clusters_64 = pd.read_csv('/content/drive/MyDrive/Inż/Plots/no_of_clusters_64_300_adap.csv', sep=',', names=['x'])
no_of_clusters_64 = no_of_clusters_64['x'].tolist()
no_of_clusters_128 = pd.read_csv('/content/drive/MyDrive/Inż/Plots/no_of_clusters_128_300_adap.csv', sep=',', names=['x'])
no_of_clusters_128 = no_of_clusters_128['x'].tolist()
no_of_clusters_256 = pd.read_csv('/content/drive/MyDrive/Inż/Plots/no_of_clusters_256_300_adap.csv', sep=',', names=['x'])
no_of_clusters_256 = no_of_clusters_256['x'].tolist()
no_of_clusters_512 = pd.read_csv('/content/drive/MyDrive/Inż/Plots/no_of_clusters_512_300_adap.csv', sep=',', names=['x'])
no_of_clusters_512 = no_of_clusters_512['x'].tolist()
no_of_clusters_1024 = pd.read_csv('/content/drive/MyDrive/Inż/Plots/no_of_clusters_1024_300_adap.csv', sep=',', names=['x'])
no_of_clusters_1024 = no_of_clusters_1024['x'].tolist()

# %%
title = "Threshold: " + str(threshold) + " - " + "No of clusters"
plt.plot(mp, no_of_clusters_32, label = "b = 32", marker = "o")
plt.plot(mp, no_of_clusters_64, label = "b = 64", marker = "x")
plt.plot(mp, no_of_clusters_128, label = "b = 128", marker = "*")
plt.plot(mp, no_of_clusters_256, label = "b = 256", linestyle = "-", marker = "o")
plt.plot(mp, no_of_clusters_512, label = "b = 512", linestyle = "-", marker = "x")
plt.plot(mp, no_of_clusters_1024, label = "b = 1024", linestyle = "-", marker = "*")
plt.title(title)
plt.legend()
plt.show()

# %% [markdown]
# # REGULAR BINS PLOTS

# %% [markdown]
# # METRICS DEPENDING ON THRESHOLD - 64 bins 0,01

# %% [markdown]
# ##RECALL

# %%
num_of_bins = 64
multiplier = [0.01 * n for n in range(1, 10)]
EPS = [ x * num_of_bins for x in multiplier]

# %%
recall_100 = pd.read_csv('/content/drive/MyDrive/Inż/Plots/recall_64_100_reg_0-01.csv', sep=',', names=['x'])
recall_100 = recall_100['x'].tolist()
recall_150 = pd.read_csv('/content/drive/MyDrive/Inż/Plots/recall_64_150_reg_0-01.csv', sep=',', names=['x'])
recall_150 = recall_150['x'].tolist()

# %%
title = "No of bins: " + str(num_of_bins) + " - " + "Recall"
plt.plot(EPS, recall_100, label = "m = 100", marker = "*")
plt.plot(EPS, recall_150, label = "m = 150", linestyle = "-", marker = "o")
plt.title(title)
plt.legend()
plt.show()

# %% [markdown]
# ##PRECISION

# %%
precision_100 = pd.read_csv('/content/drive/MyDrive/Inż/Plots/precision_64_100_reg_0-01.csv', sep=',', names=['x'])
precision_100 = precision_100['x'].tolist()
precision_150 = pd.read_csv('/content/drive/MyDrive/Inż/Plots/precision_64_150_reg_0-01.csv', sep=',', names=['x'])
precision_150 = precision_150['x'].tolist()

# %%
title = "No of bins: " + str(num_of_bins) + " - " + "Precision"
plt.plot(EPS, precision_100, label = "m = 100", marker = "*")
plt.plot(EPS, precision_150, label = "m = 150", linestyle = "-", marker = "o")
plt.title(title)
plt.legend()
plt.show()

# %% [markdown]
# ##F1 SCORE

# %%
f1_score_100 = pd.read_csv('/content/drive/MyDrive/Inż/Plots/f1_score_64_100_reg_0-01.csv', sep=',', names=['x'])
f1_score_100 = f1_score_100['x'].tolist()
f1_score_150 = pd.read_csv('/content/drive/MyDrive/Inż/Plots/f1_score_64_150_reg_0-01.csv', sep=',', names=['x'])
f1_score_150 = f1_score_150['x'].tolist()

# %%
title = "No of bins: " + str(num_of_bins) + " - " + "F1 Score"
plt.plot(EPS, f1_score_100, label = "m = 100", marker = "*")
plt.plot(EPS, f1_score_150, label = "m = 150", linestyle = "-", marker = "o")
plt.title(title)
plt.legend()
plt.show()

# %% [markdown]
# # METRICS DEPENDING ON THRESHOLD - 64 bins 0,1

# %% [markdown]
# ##RECALL

# %%
num_of_bins = 64
multiplier = [0.1 * n for n in range(1, 10)]
EPS = [ x * num_of_bins for x in multiplier]

# %%
recall_100 = pd.read_csv('/content/drive/MyDrive/Inż/Plots/recall_64_100_reg_0-1.csv', sep=',', names=['x'])
recall_100 = recall_100['x'].tolist()
recall_150 = pd.read_csv('/content/drive/MyDrive/Inż/Plots/recall_64_150_reg_0-1.csv', sep=',', names=['x'])
recall_150 = recall_150['x'].tolist()

# %%
title = "No of bins: " + str(num_of_bins) + " - " + "Recall"
plt.plot(EPS, recall_100, label = "m = 100", marker = "*")
plt.plot(EPS, recall_150, label = "m = 150", linestyle = "-", marker = "o")
plt.title(title)
plt.legend()
plt.show()

# %% [markdown]
# ##PRECISION

# %%
precision_100 = pd.read_csv('/content/drive/MyDrive/Inż/Plots/precision_64_100_reg_0-1.csv', sep=',', names=['x'])
precision_100 = precision_100['x'].tolist()
precision_150 = pd.read_csv('/content/drive/MyDrive/Inż/Plots/precision_64_150_reg_0-1.csv', sep=',', names=['x'])
precision_150 = precision_150['x'].tolist()

# %%
title = "No of bins: " + str(num_of_bins) + " - " + "Precision"
plt.plot(EPS, precision_100, label = "m = 100", marker = "*")
plt.plot(EPS, precision_150, label = "m = 150", linestyle = "-", marker = "o")
plt.title(title)
plt.legend()
plt.show()

# %% [markdown]
# ##F1 SCORE

# %%
f1_score_100 = pd.read_csv('/content/drive/MyDrive/Inż/Plots/f1_score_64_100_reg_0-1.csv', sep=',', names=['x'])
f1_score_100 = f1_score_100['x'].tolist()
f1_score_150 = pd.read_csv('/content/drive/MyDrive/Inż/Plots/f1_score_64_150_reg_0-1.csv', sep=',', names=['x'])
f1_score_150 = f1_score_150['x'].tolist()

# %%
title = "No of bins: " + str(num_of_bins) + " - " + "F1 Score"
plt.plot(EPS, f1_score_100, label = "m = 100", marker = "*")
plt.plot(EPS, f1_score_150, label = "m = 150", linestyle = "-", marker = "o")
plt.title(title)
plt.legend()
plt.show()

# %% [markdown]
# # METRICS DEPENDING ON THRESHOLD - 256 bins 0,01

# %% [markdown]
# ##RECALL

# %%
num_of_bins = 256
multiplier = [0.01 * n for n in range(1, 10)]
EPS = [ x * num_of_bins for x in multiplier]

# %%
recall_100 = pd.read_csv('/content/drive/MyDrive/Inż/Plots/recall_256_100_reg_0-01.csv', sep=',', names=['x'])
recall_100 = recall_100['x'].tolist()
recall_150 = pd.read_csv('/content/drive/MyDrive/Inż/Plots/recall_256_150_reg_0-01.csv', sep=',', names=['x'])
recall_150 = recall_150['x'].tolist()

# %%
title = "No of bins: " + str(num_of_bins) + " - " + "Recall"
plt.plot(EPS, recall_100, label = "m = 100", marker = "*")
plt.plot(EPS, recall_150, label = "m = 150", linestyle = "-", marker = "o")
plt.title(title)
plt.legend()
plt.show()

# %% [markdown]
# ##PRECISION

# %%
precision_100 = pd.read_csv('/content/drive/MyDrive/Inż/Plots/precision_256_100_reg_0-01.csv', sep=',', names=['x'])
precision_100 = precision_100['x'].tolist()
precision_150 = pd.read_csv('/content/drive/MyDrive/Inż/Plots/precision_256_150_reg_0-01.csv', sep=',', names=['x'])
precision_150 = precision_150['x'].tolist()

# %%
title = "No of bins: " + str(num_of_bins) + " - " + "Precision"
plt.plot(EPS, precision_100, label = "m = 100", marker = "*")
plt.plot(EPS, precision_150, label = "m = 150", linestyle = "-", marker = "o")
plt.title(title)
plt.legend()
plt.show()

# %% [markdown]
# ##F1 SCORE

# %%
f1_score_100 = pd.read_csv('/content/drive/MyDrive/Inż/Plots/f1_score_256_100_reg_0-01.csv', sep=',', names=['x'])
f1_score_100 = f1_score_100['x'].tolist()
f1_score_150 = pd.read_csv('/content/drive/MyDrive/Inż/Plots/f1_score_256_150_reg_0-01.csv', sep=',', names=['x'])
f1_score_150 = f1_score_150['x'].tolist()

# %%
title = "No of bins: " + str(num_of_bins) + " - " + "F1 Score"
plt.plot(EPS, f1_score_100, label = "m = 100", marker = "*")
plt.plot(EPS, f1_score_150, label = "m = 150", linestyle = "-", marker = "o")
plt.title(title)
plt.legend()
plt.show()

# %% [markdown]
# # METRICS DEPENDING ON THRESHOLD - 256 bins 0,1

# %% [markdown]
# ##RECALL

# %%
num_of_bins = 256
multiplier = [0.1 * n for n in range(1, 10)]
EPS = [ x * num_of_bins for x in multiplier]

# %%
recall_100 = pd.read_csv('/content/drive/MyDrive/Inż/Plots/recall_256_100_reg_0-1.csv', sep=',', names=['x'])
recall_100 = recall_100['x'].tolist()
recall_150 = pd.read_csv('/content/drive/MyDrive/Inż/Plots/recall_256_150_reg_0-1.csv', sep=',', names=['x'])
recall_150 = recall_150['x'].tolist()

# %%
title = "No of bins: " + str(num_of_bins) + " - " + "Recall"
plt.plot(EPS, recall_100, label = "m = 100", marker = "*")
plt.plot(EPS, recall_150, label = "m = 150", linestyle = "-", marker = "o")
plt.title(title)
plt.legend()
plt.show()

# %% [markdown]
# ##PRECISION

# %%
precision_100 = pd.read_csv('/content/drive/MyDrive/Inż/Plots/precision_256_100_reg_0-1.csv', sep=',', names=['x'])
precision_100 = precision_100['x'].tolist()
precision_150 = pd.read_csv('/content/drive/MyDrive/Inż/Plots/precision_256_150_reg_0-1.csv', sep=',', names=['x'])
precision_150 = precision_150['x'].tolist()

# %%
title = "No of bins: " + str(num_of_bins) + " - " + "Precision"
plt.plot(EPS, precision_100, label = "m = 100", marker = "*")
plt.plot(EPS, precision_150, label = "m = 150", linestyle = "-", marker = "o")
plt.title(title)
plt.legend()
plt.show()

# %% [markdown]
# ##F1 SCORE

# %%
f1_score_100 = pd.read_csv('/content/drive/MyDrive/Inż/Plots/f1_score_256_100_reg_0-1.csv', sep=',', names=['x'])
f1_score_100 = f1_score_100['x'].tolist()
f1_score_150 = pd.read_csv('/content/drive/MyDrive/Inż/Plots/f1_score_256_150_reg_0-1.csv', sep=',', names=['x'])
f1_score_150 = f1_score_150['x'].tolist()

# %%
title = "No of bins: " + str(num_of_bins) + " - " + "F1 Score"
plt.plot(EPS, f1_score_100, label = "m = 100", marker = "*")
plt.plot(EPS, f1_score_150, label = "m = 150", linestyle = "-", marker = "o")
plt.title(title)
plt.legend()
plt.show()

# %% [markdown]
# # METRICS DEPENDING ON THRESHOLD - 512 bins 0,01

# %% [markdown]
# ##RECALL

# %%
num_of_bins = 512
multiplier = [0.01 * n for n in range(1, 10)]
EPS = [ x * num_of_bins for x in multiplier]

# %%
recall_100 = pd.read_csv('/content/drive/MyDrive/Inż/Plots/recall_512_100_reg_0-01.csv', sep=',', names=['x'])
recall_100 = recall_100['x'].tolist()
recall_150 = pd.read_csv('/content/drive/MyDrive/Inż/Plots/recall_512_150_reg_0-01.csv', sep=',', names=['x'])
recall_150 = recall_150['x'].tolist()

# %%
title = "No of bins: " + str(num_of_bins) + " - " + "Recall"
plt.plot(EPS, recall_100, label = "m = 100", marker = "*")
plt.plot(EPS, recall_150, label = "m = 150", linestyle = "-", marker = "o")
plt.xlabel('EPS')
plt.title(title)
plt.legend()
plt.show()

# %% [markdown]
# ##PRECISION

# %%
precision_100 = pd.read_csv('/content/drive/MyDrive/Inż/Plots/precision_512_100_reg_0-01.csv', sep=',', names=['x'])
precision_100 = precision_100['x'].tolist()
precision_150 = pd.read_csv('/content/drive/MyDrive/Inż/Plots/precision_512_150_reg_0-01.csv', sep=',', names=['x'])
precision_150 = precision_150['x'].tolist()

# %%
title = "No of bins: " + str(num_of_bins) + " - " + "Precision"
plt.plot(EPS, precision_100, label = "m = 100", marker = "*")
plt.plot(EPS, precision_150, label = "m = 150", linestyle = "-", marker = "o")
plt.title(title)
plt.xlabel('EPS')
plt.legend()
plt.show()

# %% [markdown]
# ##F1 SCORE

# %%
f1_score_100 = pd.read_csv('/content/drive/MyDrive/Inż/Plots/f1_score_512_100_reg_0-01.csv', sep=',', names=['x'])
f1_score_100 = f1_score_100['x'].tolist()
f1_score_150 = pd.read_csv('/content/drive/MyDrive/Inż/Plots/f1_score_512_150_reg_0-01.csv', sep=',', names=['x'])
f1_score_150 = f1_score_150['x'].tolist()

# %%
title = "No of bins: " + str(num_of_bins) + " - " + "F1 Score"
plt.plot(EPS, f1_score_100, label = "m = 100", marker = "*")
plt.plot(EPS, f1_score_150, label = "m = 150", linestyle = "-", marker = "o")
plt.xlabel('EPS')
plt.title(title)
plt.legend()
plt.show()

# %% [markdown]
# # METRICS DEPENDING ON THRESHOLD - 512 bins 0,1

# %% [markdown]
# ##RECALL

# %%
num_of_bins = 512
multiplier = [0.1 * n for n in range(1, 10)]
EPS = [ x * num_of_bins for x in multiplier]

# %%
recall_100 = pd.read_csv('/content/drive/MyDrive/Inż/Plots/recall_512_100_reg_0-1.csv', sep=',', names=['x'])
recall_100 = recall_100['x'].tolist()
recall_150 = pd.read_csv('/content/drive/MyDrive/Inż/Plots/recall_512_150_reg_0-1.csv', sep=',', names=['x'])
recall_150 = recall_150['x'].tolist()

# %%
title = "No of bins: " + str(num_of_bins) + " - " + "Recall"
plt.plot(EPS, recall_100, label = "m = 100", marker = "*")
plt.plot(EPS, recall_150, label = "m = 150", linestyle = "-", marker = "o")
plt.title(title)
plt.legend()
plt.show()

# %% [markdown]
# ##PRECISION

# %%
precision_100 = pd.read_csv('/content/drive/MyDrive/Inż/Plots/precision_512_100_reg_0-1.csv', sep=',', names=['x'])
precision_100 = precision_100['x'].tolist()
precision_150 = pd.read_csv('/content/drive/MyDrive/Inż/Plots/precision_512_150_reg_0-1.csv', sep=',', names=['x'])
precision_150 = precision_150['x'].tolist()

# %%
title = "No of bins: " + str(num_of_bins) + " - " + "Precision"
plt.plot(EPS, precision_100, label = "m = 100", marker = "*")
plt.plot(EPS, precision_150, label = "m = 150", linestyle = "-", marker = "o")
plt.title(title)
plt.legend()
plt.show()

# %% [markdown]
# ##F1 SCORE

# %%
f1_score_100 = pd.read_csv('/content/drive/MyDrive/Inż/Plots/f1_score_512_100_reg_0-1.csv', sep=',', names=['x'])
f1_score_100 = f1_score_100['x'].tolist()
f1_score_150 = pd.read_csv('/content/drive/MyDrive/Inż/Plots/f1_score_512_150_reg_0-1.csv', sep=',', names=['x'])
f1_score_150 = f1_score_150['x'].tolist()

# %%
title = "No of bins: " + str(num_of_bins) + " - " + "F1 Score"
plt.plot(EPS, f1_score_100, label = "m = 100", marker = "*")
plt.plot(EPS, f1_score_150, label = "m = 150", linestyle = "-", marker = "o")
plt.title(title)
plt.legend()
plt.show()

# %% [markdown]
# # BINS DEPENDING ON EPS 0,01 - THRESHOLD 100

# %% [markdown]
# ##RECALL

# %%
mp = [0.01 * n for n in range(1, 10)]
threshold = 100

# %%
recall_64 = pd.read_csv('/content/drive/MyDrive/Inż/Plots/recall_64_100_reg_0-01.csv', sep=',', names=['x'])
recall_64 = recall_64['x'].tolist()
recall_256 = pd.read_csv('/content/drive/MyDrive/Inż/Plots/recall_256_100_reg_0-01.csv', sep=',', names=['x'])
recall_256 = recall_256['x'].tolist()
recall_512 = pd.read_csv('/content/drive/MyDrive/Inż/Plots/recall_512_100_reg_0-01.csv', sep=',', names=['x'])

# %%
title = "Threshold: " + str(threshold) + " - " + "Recall"
plt.plot(mp, recall_64, label = "b = 64", marker = "x")
plt.plot(mp, recall_256, label = "b = 256", linestyle = "-", marker = "o")
plt.plot(mp, recall_512, label = "b = 512", linestyle = "-", marker = "x")
plt.title(title)
plt.legend()
plt.show()

# %% [markdown]
# ##PRECISION

# %%
precision_64 = pd.read_csv('/content/drive/MyDrive/Inż/Plots/precision_64_100_reg_0-01.csv', sep=',', names=['x'])
precision_64 = precision_64['x'].tolist()
precision_256 = pd.read_csv('/content/drive/MyDrive/Inż/Plots/precision_256_100_reg_0-01.csv', sep=',', names=['x'])
precision_256 = precision_256['x'].tolist()
precision_512 = pd.read_csv('/content/drive/MyDrive/Inż/Plots/precision_512_100_reg_0-01.csv', sep=',', names=['x'])
precision_512 = precision_512['x'].tolist()

# %%
title = "Threshold: " + str(threshold) + " - " + "Precision"
plt.plot(mp, precision_64, label = "b = 64", marker = "x")
plt.plot(mp, precision_256, label = "b = 256", linestyle = "-", marker = "o")
plt.plot(mp, precision_512, label = "b = 512", linestyle = "-", marker = "x")
plt.title(title)
plt.legend()
plt.show()

# %% [markdown]
# ##F1_SCORE

# %%
f1_score_64 = pd.read_csv('/content/drive/MyDrive/Inż/Plots/f1_score_64_100_reg_0-01.csv', sep=',', names=['x'])
f1_score_64 = f1_score_64['x'].tolist()
f1_score_256 = pd.read_csv('/content/drive/MyDrive/Inż/Plots/f1_score_256_100_reg_0-01.csv', sep=',', names=['x'])
f1_score_256 = f1_score_256['x'].tolist()
f1_score_512 = pd.read_csv('/content/drive/MyDrive/Inż/Plots/f1_score_512_100_reg_0-01.csv', sep=',', names=['x'])
f1_score_512 = f1_score_512['x'].tolist()

# %%
title = "Threshold: " + str(threshold) + " - " + "F1 Score"

plt.plot(mp, f1_score_64, label = "b = 64", marker = "x")

plt.plot(mp, f1_score_256, label = "b = 256", linestyle = "-", marker = "o")
plt.plot(mp, f1_score_512, label = "b = 512", linestyle = "-", marker = "x")

plt.title(title)
plt.legend()
plt.show()

# %% [markdown]
# ##NO OF CLUSTERS

# %%
no_of_clusters_64 = pd.read_csv('/content/drive/MyDrive/Inż/Plots/no_of_clusters_64_100_reg_0-01.csv', sep=',', names=['x'])
no_of_clusters_64 = no_of_clusters_64['x'].tolist()

no_of_clusters_256 = pd.read_csv('/content/drive/MyDrive/Inż/Plots/no_of_clusters_256_100_reg_0-01.csv', sep=',', names=['x'])
no_of_clusters_256 = no_of_clusters_256['x'].tolist()
no_of_clusters_512 = pd.read_csv('/content/drive/MyDrive/Inż/Plots/no_of_clusters_512_100_reg_0-01.csv', sep=',', names=['x'])
no_of_clusters_512 = no_of_clusters_512['x'].tolist()

# %%
title = "Threshold: " + str(threshold) + " - " + "No of clusters"

plt.plot(mp, no_of_clusters_64, label = "b = 64", marker = "x")
plt.plot(mp, no_of_clusters_256, label = "b = 256", linestyle = "-", marker = "o")
plt.plot(mp, no_of_clusters_512, label = "b = 512", linestyle = "-", marker = "x")
plt.title(title)
plt.legend()
plt.show()

# %% [markdown]
# # BINS DEPENDING ON EPS 0,1 - THRESHOLD 100

# %% [markdown]
# ##RECALL

# %%
mp = [0.1 * n for n in range(1, 10)]
threshold = 100

# %%
recall_64 = pd.read_csv('/content/drive/MyDrive/Inż/Plots/recall_64_100_reg_0-1.csv', sep=',', names=['x'])
recall_64 = recall_64['x'].tolist()
recall_256 = pd.read_csv('/content/drive/MyDrive/Inż/Plots/recall_256_100_reg_0-1.csv', sep=',', names=['x'])
recall_256 = recall_256['x'].tolist()
recall_512 = pd.read_csv('/content/drive/MyDrive/Inż/Plots/recall_512_100_reg_0-1.csv', sep=',', names=['x'])

# %%
title = "Threshold: " + str(threshold) + " - " + "Recall"
plt.plot(mp, recall_64, label = "b = 64", marker = "x")
plt.plot(mp, recall_256, label = "b = 256", linestyle = "-", marker = "o")
plt.plot(mp, recall_512, label = "b = 512", linestyle = "-", marker = "x")
plt.title(title)
plt.legend()
plt.show()

# %% [markdown]
# ##PRECISION

# %%
precision_64 = pd.read_csv('/content/drive/MyDrive/Inż/Plots/precision_64_100_reg_0-1.csv', sep=',', names=['x'])
precision_64 = precision_64['x'].tolist()
precision_256 = pd.read_csv('/content/drive/MyDrive/Inż/Plots/precision_256_100_reg_0-1.csv', sep=',', names=['x'])
precision_256 = precision_256['x'].tolist()
precision_512 = pd.read_csv('/content/drive/MyDrive/Inż/Plots/precision_512_100_reg_0-1.csv', sep=',', names=['x'])
precision_512 = precision_512['x'].tolist()

# %%
title = "Threshold: " + str(threshold) + " - " + "Precision"
plt.plot(mp, precision_64, label = "b = 64", marker = "x")
plt.plot(mp, precision_256, label = "b = 256", linestyle = "-", marker = "o")
plt.plot(mp, precision_512, label = "b = 512", linestyle = "-", marker = "x")
plt.title(title)
plt.legend()
plt.show()

# %% [markdown]
# ##F1_SCORE

# %%
f1_score_64 = pd.read_csv('/content/drive/MyDrive/Inż/Plots/f1_score_64_100_reg_0-1.csv', sep=',', names=['x'])
f1_score_64 = f1_score_64['x'].tolist()
f1_score_256 = pd.read_csv('/content/drive/MyDrive/Inż/Plots/f1_score_256_100_reg_0-1.csv', sep=',', names=['x'])
f1_score_256 = f1_score_256['x'].tolist()
f1_score_512 = pd.read_csv('/content/drive/MyDrive/Inż/Plots/f1_score_512_100_reg_0-1.csv', sep=',', names=['x'])
f1_score_512 = f1_score_512['x'].tolist()

# %%
title = "Threshold: " + str(threshold) + " - " + "F1 Score"

plt.plot(mp, f1_score_64, label = "b = 64", marker = "x")

plt.plot(mp, f1_score_256, label = "b = 256", linestyle = "-", marker = "o")
plt.plot(mp, f1_score_512, label = "b = 512", linestyle = "-", marker = "x")

plt.title(title)
plt.legend()
plt.show()

# %% [markdown]
# ##NO OF CLUSTERS

# %%
no_of_clusters_64 = pd.read_csv('/content/drive/MyDrive/Inż/Plots/no_of_clusters_64_100_reg_0-1.csv', sep=',', names=['x'])
no_of_clusters_64 = no_of_clusters_64['x'].tolist()

no_of_clusters_256 = pd.read_csv('/content/drive/MyDrive/Inż/Plots/no_of_clusters_256_100_reg_0-1.csv', sep=',', names=['x'])
no_of_clusters_256 = no_of_clusters_256['x'].tolist()
no_of_clusters_512 = pd.read_csv('/content/drive/MyDrive/Inż/Plots/no_of_clusters_512_100_reg_0-1.csv', sep=',', names=['x'])
no_of_clusters_512 = no_of_clusters_512['x'].tolist()

# %%
title = "Threshold: " + str(threshold) + " - " + "No of clusters"

plt.plot(mp, no_of_clusters_64, label = "b = 64", marker = "x")
plt.plot(mp, no_of_clusters_256, label = "b = 256", linestyle = "-", marker = "o")
plt.plot(mp, no_of_clusters_512, label = "b = 512", linestyle = "-", marker = "x")
plt.title(title)
plt.legend()
plt.show()

# %% [markdown]
# # BINS DEPENDING ON EPS 0,01 - THRESHOLD 150

# %% [markdown]
# ##RECALL

# %%
mp = [0.01 * n for n in range(1, 10)]
threshold = 150

# %%
recall_64 = pd.read_csv('/content/drive/MyDrive/Inż/Plots/recall_64_150_reg_0-01.csv', sep=',', names=['x'])
recall_64 = recall_64['x'].tolist()
recall_256 = pd.read_csv('/content/drive/MyDrive/Inż/Plots/recall_256_150_reg_0-01.csv', sep=',', names=['x'])
recall_256 = recall_256['x'].tolist()
recall_512 = pd.read_csv('/content/drive/MyDrive/Inż/Plots/recall_512_150_reg_0-01.csv', sep=',', names=['x'])

# %%
title = "Threshold: " + str(threshold) + " - " + "Recall"
plt.plot(mp, recall_64, label = "b = 64", marker = "x")
plt.plot(mp, recall_256, label = "b = 256", linestyle = "-", marker = "o")
plt.plot(mp, recall_512, label = "b = 512", linestyle = "-", marker = "x")
plt.title(title)
plt.legend()
plt.show()

# %% [markdown]
# ##PRECISION

# %%
precision_64 = pd.read_csv('/content/drive/MyDrive/Inż/Plots/precision_64_150_reg_0-01.csv', sep=',', names=['x'])
precision_64 = precision_64['x'].tolist()
precision_256 = pd.read_csv('/content/drive/MyDrive/Inż/Plots/precision_256_150_reg_0-01.csv', sep=',', names=['x'])
precision_256 = precision_256['x'].tolist()
precision_512 = pd.read_csv('/content/drive/MyDrive/Inż/Plots/precision_512_150_reg_0-01.csv', sep=',', names=['x'])
precision_512 = precision_512['x'].tolist()

# %%
title = "Threshold: " + str(threshold) + " - " + "Precision"
plt.plot(mp, precision_64, label = "b = 64", marker = "x")
plt.plot(mp, precision_256, label = "b = 256", linestyle = "-", marker = "o")
plt.plot(mp, precision_512, label = "b = 512", linestyle = "-", marker = "x")
plt.title(title)
plt.legend()
plt.show()

# %% [markdown]
# ##F1_SCORE

# %%
f1_score_64 = pd.read_csv('/content/drive/MyDrive/Inż/Plots/f1_score_64_150_reg_0-01.csv', sep=',', names=['x'])
f1_score_64 = f1_score_64['x'].tolist()
f1_score_256 = pd.read_csv('/content/drive/MyDrive/Inż/Plots/f1_score_256_150_reg_0-01.csv', sep=',', names=['x'])
f1_score_256 = f1_score_256['x'].tolist()
f1_score_512 = pd.read_csv('/content/drive/MyDrive/Inż/Plots/f1_score_512_150_reg_0-01.csv', sep=',', names=['x'])
f1_score_512 = f1_score_512['x'].tolist()

# %%
title = "Threshold: " + str(threshold) + " - " + "F1 Score"

plt.plot(mp, f1_score_64, label = "b = 64", marker = "x")

plt.plot(mp, f1_score_256, label = "b = 256", linestyle = "-", marker = "o")
plt.plot(mp, f1_score_512, label = "b = 512", linestyle = "-", marker = "x")

plt.title(title)
plt.legend()
plt.show()

# %% [markdown]
# ##NO OF CLUSTERS

# %%
no_of_clusters_64 = pd.read_csv('/content/drive/MyDrive/Inż/Plots/no_of_clusters_64_150_reg_0-01.csv', sep=',', names=['x'])
no_of_clusters_64 = no_of_clusters_64['x'].tolist()

no_of_clusters_256 = pd.read_csv('/content/drive/MyDrive/Inż/Plots/no_of_clusters_256_150_reg_0-01.csv', sep=',', names=['x'])
no_of_clusters_256 = no_of_clusters_256['x'].tolist()
no_of_clusters_512 = pd.read_csv('/content/drive/MyDrive/Inż/Plots/no_of_clusters_512_150_reg_0-01.csv', sep=',', names=['x'])
no_of_clusters_512 = no_of_clusters_512['x'].tolist()

# %%
title = "Threshold: " + str(threshold) + " - " + "No of clusters"

plt.plot(mp, no_of_clusters_64, label = "b = 64", marker = "x")
plt.plot(mp, no_of_clusters_256, label = "b = 256", linestyle = "-", marker = "o")
plt.plot(mp, no_of_clusters_512, label = "b = 512", linestyle = "-", marker = "x")
plt.title(title)
plt.legend()
plt.show()

# %% [markdown]
# # BINS DEPENDING ON EPS 0,1 - THRESHOLD 150

# %% [markdown]
# ##RECALL

# %%
mp = [0.1 * n for n in range(1, 10)]
threshold = 150

# %%
recall_64 = pd.read_csv('/content/drive/MyDrive/Inż/Plots/recall_64_150_reg_0-1.csv', sep=',', names=['x'])
recall_64 = recall_64['x'].tolist()
recall_256 = pd.read_csv('/content/drive/MyDrive/Inż/Plots/recall_256_150_reg_0-1.csv', sep=',', names=['x'])
recall_256 = recall_256['x'].tolist()
recall_512 = pd.read_csv('/content/drive/MyDrive/Inż/Plots/recall_512_150_reg_0-1.csv', sep=',', names=['x'])

# %%
title = "Threshold: " + str(threshold) + " - " + "Recall"
plt.plot(mp, recall_64, label = "b = 64", marker = "x")
plt.plot(mp, recall_256, label = "b = 256", linestyle = "-", marker = "o")
plt.plot(mp, recall_512, label = "b = 512", linestyle = "-", marker = "x")
plt.title(title)
plt.legend()
plt.show()

# %% [markdown]
# ##PRECISION

# %%
precision_64 = pd.read_csv('/content/drive/MyDrive/Inż/Plots/precision_64_150_reg_0-1.csv', sep=',', names=['x'])
precision_64 = precision_64['x'].tolist()
precision_256 = pd.read_csv('/content/drive/MyDrive/Inż/Plots/precision_256_150_reg_0-1.csv', sep=',', names=['x'])
precision_256 = precision_256['x'].tolist()
precision_512 = pd.read_csv('/content/drive/MyDrive/Inż/Plots/precision_512_150_reg_0-1.csv', sep=',', names=['x'])
precision_512 = precision_512['x'].tolist()

# %%
title = "Threshold: " + str(threshold) + " - " + "Precision"
plt.plot(mp, precision_64, label = "b = 64", marker = "x")
plt.plot(mp, precision_256, label = "b = 256", linestyle = "-", marker = "o")
plt.plot(mp, precision_512, label = "b = 512", linestyle = "-", marker = "x")
plt.title(title)
plt.legend()
plt.show()

# %% [markdown]
# ##F1_SCORE

# %%
f1_score_64 = pd.read_csv('/content/drive/MyDrive/Inż/Plots/f1_score_64_150_reg_0-1.csv', sep=',', names=['x'])
f1_score_64 = f1_score_64['x'].tolist()
f1_score_256 = pd.read_csv('/content/drive/MyDrive/Inż/Plots/f1_score_256_150_reg_0-1.csv', sep=',', names=['x'])
f1_score_256 = f1_score_256['x'].tolist()
f1_score_512 = pd.read_csv('/content/drive/MyDrive/Inż/Plots/f1_score_512_150_reg_0-1.csv', sep=',', names=['x'])
f1_score_512 = f1_score_512['x'].tolist()

# %%
title = "Threshold: " + str(threshold) + " - " + "F1 Score"

plt.plot(mp, f1_score_64, label = "b = 64", marker = "x")

plt.plot(mp, f1_score_256, label = "b = 256", linestyle = "-", marker = "o")
plt.plot(mp, f1_score_512, label = "b = 512", linestyle = "-", marker = "x")

plt.title(title)
plt.legend()
plt.show()

# %% [markdown]
# ##NO OF CLUSTERS

# %%
no_of_clusters_64 = pd.read_csv('/content/drive/MyDrive/Inż/Plots/no_of_clusters_64_150_reg_0-1.csv', sep=',', names=['x'])
no_of_clusters_64 = no_of_clusters_64['x'].tolist()

no_of_clusters_256 = pd.read_csv('/content/drive/MyDrive/Inż/Plots/no_of_clusters_256_150_reg_0-1.csv', sep=',', names=['x'])
no_of_clusters_256 = no_of_clusters_256['x'].tolist()
no_of_clusters_512 = pd.read_csv('/content/drive/MyDrive/Inż/Plots/no_of_clusters_512_150_reg_0-1.csv', sep=',', names=['x'])
no_of_clusters_512 = no_of_clusters_512['x'].tolist()

# %%
title = "Threshold: " + str(threshold) + " - " + "No of clusters"

plt.plot(mp, no_of_clusters_64, label = "b = 64", marker = "x")
plt.plot(mp, no_of_clusters_256, label = "b = 256", linestyle = "-", marker = "o")
plt.plot(mp, no_of_clusters_512, label = "b = 512", linestyle = "-", marker = "x")
plt.title(title)
plt.legend()
plt.show()
